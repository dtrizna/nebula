# %%
import matplotlib.pyplot as plt
import numpy as np
import os

basefolder = "optim_scheduler_limit_1000_1677436102"
lrs = [x for x in os.listdir(os.path.join(basefolder, "training_files")) if "learning_rates" in x]
# take every 3rd elemets from the list
lrs = [os.path.join(basefolder, "training_files", x) for x in lrs[::3]]
lrs = [np.load(x) for x in lrs]
lrs_sequence = [
        "gpt",
        "step",
        "triangular",
        "onecycle",
        "cosine"
    ]
lrs_dict = dict(zip(lrs_sequence, lrs))

# lineplot each learning rate
fig, ax = plt.subplots(figsize=(10, 5))
for lr in lrs_dict:
    ax.plot(lrs_dict[lr], label=lr)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=5)
ax.grid()

# %% [markdown]
# GPT schedule is broken ....

# %%
import matplotlib.pyplot as plt
import numpy as np
import os

basefolder = "optim_scheduler_limit_None_1677436527"
lrs = [x for x in os.listdir(os.path.join(basefolder, "training_files")) if "learning_rates" in x]
# take every 3rd elemets from the list
lrs = [os.path.join(basefolder, "training_files", x) for x in lrs[::3]]
lrs = [np.load(x) for x in lrs]
lrs_sequence = [
        "step",
        "triangular",
        "onecycle",
        "cosine"
    ]
lrs_dict = dict(zip(lrs_sequence, lrs))

# lineplot each learning rate
fig, ax = plt.subplots(figsize=(10, 5))
for lr in lrs_dict:
    ax.plot(lrs_dict[lr], label=lr)
ax.legend(loc='lower center', bbox_to_anchor=(0.5, -0.2), ncol=5)
ax.grid()
