# %%
import os
import json
import torch
torch.set_grad_enabled(False)
import numpy as np
from pprint import pprint
import sys
sys.path.append('../..')
from nebula.models.attention import TransformerEncoderModel, TransformerEncoderChunks
from nebula import PEDynamicFeatureExtractor
from nebula.preprocessing import JSONTokenizerNaive, JSONTokenizerBPE
from nebula.misc import get_path, clear_cuda_cache, set_random_seed
from nebula.constants import *
from bertviz import model_view, head_view
from collections import Counter

from copy import deepcopy
from tqdm import tqdm
DEVICE = "cpu" #"cuda"

import matplotlib.pyplot as plt

SCRIPT_PATH = get_path(type="notebook")
ROOT = os.path.join(SCRIPT_PATH, "..", "..")

# %%
# done three folds on that run
MODEL_IDX = 1

# BPE
datafolder = os.path.join(ROOT, r"evaluation\paper_sota\out_speakeasy\nebula_speakeasy_vocab_50000_seqlen_512")
model_folder = os.path.join(ROOT, r"evaluation\paper_sota\out_speakeasy\cv_nebula_limNone_r1763_t20\training_files")

# Whitespace
# datafolder = os.path.join(ROOT, r"evaluation\paper_ablation\out_tokenizer\nebula_whitespace_vocab_50000_seqlen_512")
# model_folder = os.path.join(ROOT, r"evaluation\paper_ablation\out_tokenizer\cv_whitespace_limNone_r1763_t5\training_files")

# LOADING OBJECTS
model_file = [x for x in os.listdir(model_folder) if x.endswith(".torch")][MODEL_IDX]
model_file_fullpath = os.path.join(model_folder, model_file)
state_dict = torch.load(model_file_fullpath)
state_dict = torch.load(model_file_fullpath)

with open(os.path.join(datafolder, f"tokenizer_50000_vocab.json")) as f:
    nebula_vocab = json.load(f)

# BPE
tokenizer = JSONTokenizerBPE(
    vocab_size=len(nebula_vocab),
    seq_len=512,
    model_path=os.path.join(ROOT, datafolder, r"tokenizer_50000.model")
)

# Whitespace
# tokenizer = JSONTokenizerNaive(
#     vocab_size=len(nebula_vocab),
#     seq_len=512,
#     vocab=nebula_vocab
# )

model_config = {
        "vocab_size": len(nebula_vocab),
        "maxlen": 512,
        "chunk_size": 64,
        "dModel": 64,  # embedding & transformer dimension
        "nHeads": 8,  # number of heads in nn.MultiheadAttention
        "dHidden": 256,  # dimension of the feedforward network model in nn.TransformerEncoder
        "nLayers": 2,  # number of nn.TransformerEncoderLayer in nn.TransformerEncoder
        "numClasses": 1, # binary classification
        "hiddenNeurons": [64],
        "layerNorm": False,
        "dropout": 0.3,
        "mean_over_sequence": False,
        "norm_first": True
    }
model = TransformerEncoderChunks(**model_config)
model.load_state_dict(state_dict)
_ = model.to(DEVICE)


MODEL_CONFIG = model_config
TOKENIZER = tokenizer
STATE_DICT = state_dict
def get_score(example, title="this sample"):
    random_seed = 1492
    set_random_seed(random_seed)
    model = TransformerEncoderChunks(**MODEL_CONFIG).to(DEVICE)
    model.load_state_dict(STATE_DICT)
    model.eval()
    extractor = PEDynamicFeatureExtractor()
    exampleProcessed = extractor.filter_and_normalize_report(example)

    exampleTokenized = TOKENIZER.tokenize(exampleProcessed)
    if len(exampleTokenized) == 1:
        exampleTokenized = exampleTokenized[0]
    exampleEncoded = TOKENIZER.encode(exampleProcessed)
    x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

    logit_bad = model(x[:, :512]).cpu()
    prob_bad = torch.sigmoid(logit_bad)
    print(f"  [!] Model scores on {title:>20} -- logit: {logit_bad[0][0].numpy():^8.4f} and probability: {prob_bad[0][0].numpy():.4f}")
    return logit_bad.numpy()[0][0]
# Out:
# WARNING:root: [!] Successfully loaded pre-trained tokenizer model!
# WARNING:root: [!] Loaded vocab with size 50001 from C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\evaluation\paper_sota\out_speakeasy\nebula_speakeasy_vocab_50000_seqlen_512\tokenizer_50000_vocab.json

# %%
def get_attn(x, model):
    attentions = []
    x = model.pos_encoder(model.encoder(x))
    for layer in model.transformer_encoder.layers:
        this_layer_attn = layer.self_attn(x,x,x, average_attn_weights=False)[1]
        attentions.append(this_layer_attn.cpu())
        x = layer(x)
    return attentions

def viz(start, end, attentions, exampleTokenized, threshold=0.005, layer=1, heads=[]):
    m = 1/threshold
    tokens = exampleTokenized[start:end]
    att_crop = [x[:, :, start:end, start:end]*m for x in attentions]
    head_view(att_crop, tokens, prettify_tokens=False, heads=heads, layer=layer)

def report_where_attends(seq_1, seq_2, token_location, tokenized_input):
    # TODO: somewhat broken?
    msg = ""
    token = tokenized_input[token_location]
    where_attends_seq_2 = np.where(seq_1 == token_location)[0]
    if len(where_attends_seq_2) > 0:
        counterpart_tokens = list(set([tokenized_input[x] for x in seq_2[where_attends_seq_2].tolist()]))
        if token in counterpart_tokens:
            counterpart_tokens.remove(token)
        if counterpart_tokens: # TODO: this part reports wrong results
            msg = f"\t  It has connections with tokens at following locations and values:\n"
            msg += f"\t\tLocated: {where_attends_seq_2}\n"
            msg += f"\t\tValues: {counterpart_tokens}\n"
    return msg

def analyze_attentions(attentions, tokenized_input, threshold=0.005, diff=20, most_common=5, types=["proximity", "frequency"], limit=20, verbose=True):
    counter = 0
    print(f"\n[!] Analyzing attentions based on {types}... ")
    for layer_nr, layer in enumerate(attentions):
        idxs = np.where(layer > threshold)
        print(f"\n[!] Total {len(idxs[0])} tokens has strong activations at layer {layer_nr} with threshold: {threshold}!")
        if len(idxs[0]) > 0:
            heads = idxs[1].tolist()
            attn_seq_1 = idxs[2]
            attn_seq_2 = idxs[3]

            if "proximity" in types:
                # PROXIMITY CHECK
                print(f"[*] Performing a token attention proximity check with token difference: {diff}... ")
                for j, (a1, a2) in enumerate(zip(attn_seq_1, attn_seq_2)):
                    # check if difference between a1 and a2 is below threshold
                    token_at_a1 = tokenized_input[a1]
                    token_at_a2 = tokenized_input[a2]  
                    if abs(a1 - a2) > diff:
                        if verbose:
                            print(f"\tThese two tokens has strong activations but are far (diff: {abs(a1 - a2)}):\n\t\t{token_at_a1}\n\t\t{token_at_a2}")
                    elif abs(a1 - a2) <= diff:
                        counter += 1
                        if counter > limit:
                            return
                        which_heads = heads[j]
                        print("\tThese two close sequence tokens has strong activations:", a1, a2, f"at layer {layer_nr} head", which_heads)
                        print(f"\t\tToken at location {a1} -> {token_at_a1}")
                        print(f"\t\tToken at location {a2} -> {token_at_a2}")
                        aa = sorted([a1, a2])
                        a1, a2 = aa[0]-5, aa[1]+5
                        if a1 < 0:
                            a1 = 0
                        if a2 > len(tokenized_input):
                            a2 = len(tokenized_input)
                        vizString = f"viz({a1}, {a2}, attentions, tokenized_input, layer={layer_nr}, heads=[{which_heads}])"
                        print("Calling:", vizString)
                        viz(a1, a2, attentions, tokenized_input, layer=layer_nr, heads=[which_heads])
            if "count" in types or "frequency" in types:
                # COUNTER CHECK
                print("[*] Performing a token frequency check ... ")
                c = attn_seq_2.tolist()
                c.extend((attn_seq_1.tolist()))
                c = Counter(c).most_common(most_common)        
                for token_location, token_frequency in c:
                    appear_in_heads = [heads[i] for i in np.where(attn_seq_1 == token_location)[0].tolist()]
                    appear_in_heads.extend([heads[i] for i in np.where(attn_seq_2 == token_location)[0].tolist()])
                    appear_in_heads = list(set(appear_in_heads))

                    token_value = tokenized_input[token_location]
                    msg1 = report_where_attends(attn_seq_1, attn_seq_2, token_location, tokenized_input)
                    msg2 = report_where_attends(attn_seq_2, attn_seq_2, token_location, tokenized_input)
                    if msg1 or msg2:
                        msg = f"\n\t> Token '{token_value}' location in sequence: {token_location}\n"
                        msg += f"\t  It appears {token_frequency} times, in layer {layer_nr}, heads: {appear_in_heads}\n"
                        msg += msg1 + msg2
                        print(msg)
                        
                        counter += 1
                        if counter > limit:
                            return

def get_attention_report(exampleFile, model, tokenizer, maxLen=512, random_seed=42, diff=20, threshold=0.004, limit=20, verbose=True):
    if isinstance(exampleFile, str) and os.path.exists(exampleFile):        
        with open(exampleFile) as f:
            example = json.load(f)
    elif isinstance(exampleFile, (dict, list)):
        example = exampleFile
    else:
        raise FileNotFoundError

    extractor = PEDynamicFeatureExtractor()
    exampleProcessed = extractor.filter_and_normalize_report(example[0])
    
    exampleTokenized = tokenizer.tokenize(exampleProcessed)
    if len(exampleTokenized) == 1:
        exampleTokenized = exampleTokenized[0]
    exampleEncoded = tokenizer.encode(exampleProcessed)
    x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

    logit_bad = model(x[:, :maxLen]).cpu()
    prob_bad = torch.sigmoid(logit_bad)
    print("[!] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())

    clear_cuda_cache()
    set_random_seed(random_seed)
    attentions = get_attn(x, model)
    analyze_attentions(attentions, exampleTokenized, types=["proximity"], threshold=threshold, diff=diff, limit=limit, verbose=verbose)
    analyze_attentions(attentions, exampleTokenized, types=["frequency"], most_common=10, limit=limit, threshold=threshold)
    return attentions, exampleTokenized

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

# https://www.virustotal.com/gui/file/0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
attentions, tokenized_input = get_attention_report(exampleFile, model, tokenizer, maxLen=512, random_seed=1492, diff=15, threshold=0.0025, limit=2, verbose=False)
# Out:
# [!] Model scores on this sample -- logit: 49.34703  and probability: 1.0
#
# [!] Analyzing attentions based on ['proximity']...
#
# [!] Total 12 tokens has strong activations at layer 0 with threshold: 0.0025!
# [*] Performing a token attention proximity check with token difference: 15...
#
# [!] Total 490 tokens has strong activations at layer 1 with threshold: 0.0025!
# [*] Performing a token attention proximity check with token difference: 15...
# 	These two close sequence tokens has strong activations: 202 209 at layer 1 head 7
# 		Token at location 202 -> ▁0x77000000
# 		Token at location 209 -> args
# Calling: viz(197, 214, attentions, tokenized_input, layer=1, heads=[7])
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-01321321c91e4bc99ac1b5ccb1465192" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
# 	These two close sequence tokens has strong activations: 223 209 at layer 1 head 7
# 		Token at location 223 -> ▁0x77000000
# 		Token at location 209 -> args
# Calling: viz(204, 228, attentions, tokenized_input, layer=1, heads=[7])
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"></script>
#
#         <div id="bertviz-a7db5a4ef5994bfb880eb540670856ca" style="font-family:'Helvetica Neue', Helvetica, Arial, sans-serif;">
#             <span style="user-select:none">
#                 Layer: <select id="layer"></select>
#
#             </span>
#             <div id='vis'></div>
#         </div>
# [!] Analyzing attentions based on ['frequency']...
#
# [!] Total 12 tokens has strong activations at layer 0 with threshold: 0.0025!
# [*] Performing a token frequency check ...
#
# 	> Token 'getsystemtimeasfiletime' location in sequence: 94
# 	  It appears 1 times, in layer 0, heads: [7]
# 	  It has connections with tokens at following locations and values:
# 		Located: [0]
# 		Values: ['ame']
#
#
# 	> Token '▁kernel32' location in sequence: 684
# 	  It appears 1 times, in layer 0, heads: [7]
# 	  It has connections with tokens at following locations and values:
# 		Located: [1]
# 		Values: ['ame']
#
#
# 	> Token '▁' location in sequence: 762
# 	  It appears 1 times, in layer 0, heads: [7]
# 	  It has connections with tokens at following locations and values:
# 		Located: [2]
# 		Values: ['ame']

# %% [markdown]
# # Adversarial examples

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
print(exampleFile)
with open(exampleFile) as f:
    exampleFile = json.load(f)
# Out:
# C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json

# %%
get_score(exampleFile)
# Out:
#   [!] Model scores on this sample -- logit: 75.91932  and probability: 1.0

# %% [markdown]
# ## Adding legitimate APIs at the beginning
#
# ### Single legitimate API
#
# #### Once

# %%
legit_api = {
                "pc": "0x4015f0",
                "api_name": "msvcrt.memset",
                "args": [
                    "0x1211d8c",
                    "0x0",
                    "0x1fc"
                ],
                "ret_val": "0x1211d8c"
            }

orig_apis = deepcopy(exampleFile[0]['apis'])
adversarial_example = deepcopy(exampleFile)
adversarial_example[0]['apis'] = [legit_api] + orig_apis
print(f"  [!] Len orig apis: {len(orig_apis)} and len adversarial apis: {len(adversarial_example[0]['apis'])}")
_ = get_score(adversarial_example)
# Out:
#   [!] Len orig apis: 490 and len adversarial apis: 491
#   [!] Model scores on this sample -- logit: 70.66313  and probability: 1.0

# %% [markdown]
# #### Increasing loop

# %%
legit_api = {
                "pc": "0x4015f0",
                "api_name": "msvcrt.memset",
                "args": [
                    "0x1211d8c",
                    "0x0",
                    "0x1fc"
                ],
                "ret_val": "0x1211d8c"
            }

logits_api = []
for i in range(0, 20, 1):
    print(f"  [!] Iteration {i}")
    orig_apis = deepcopy(exampleFile[0]['apis'])
    adversarial_example = deepcopy(exampleFile)
    adversarial_example[0]['apis'] = i*[legit_api] + orig_apis
    print(f"  [!] Len orig apis: {len(orig_apis)} and len adversarial apis: {len(adversarial_example[0]['apis'])}")
    l = get_score(adversarial_example)
    logits_api.append(l)
# Out:
#   [!] Iteration 0
#   [!] Len orig apis: 490 and len adversarial apis: 490
#   [!] Model scores on          this sample -- logit: 75.9193  and probability: 1.0000
#   [!] Iteration 1
#   [!] Len orig apis: 490 and len adversarial apis: 491
#   [!] Model scores on          this sample -- logit: 70.6631  and probability: 1.0000
#   [!] Iteration 2
#   [!] Len orig apis: 490 and len adversarial apis: 492
#   [!] Model scores on          this sample -- logit: 64.2084  and probability: 1.0000
#   [!] Iteration 3
#   [!] Len orig apis: 490 and len adversarial apis: 493
#   [!] Model scores on          this sample -- logit: 63.3084  and probability: 1.0000
#   [!] Iteration 4
#   [!] Len orig apis: 490 and len adversarial apis: 494
#   [!] Model scores on          this sample -- logit: 66.3087  and probability: 1.0000
#   [!] Iteration 5
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 69.4387  and probability: 1.0000
#   [!] Iteration 6
#   [!] Len orig apis: 490 and len adversarial apis: 496
#   [!] Model scores on          this sample -- logit: 65.8233  and probability: 1.0000
#   [!] Iteration 7
#   [!] Len orig apis: 490 and len adversarial apis: 497
#   [!] Model scores on          this sample -- logit: 71.0495  and probability: 1.0000
#   [!] Iteration 8
#   [!] Len orig apis: 490 and len adversarial apis: 498
#   [!] Model scores on          this sample -- logit: 72.9081  and probability: 1.0000
#   [!] Iteration 9
#   [!] Len orig apis: 490 and len adversarial apis: 499
#   [!] Model scores on          this sample -- logit: 72.5377  and probability: 1.0000
#   [!] Iteration 10
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 74.2600  and probability: 1.0000
#   [!] Iteration 11
#   [!] Len orig apis: 490 and len adversarial apis: 501
#   [!] Model scores on          this sample -- logit: 76.8666  and probability: 1.0000
#   [!] Iteration 12
#   [!] Len orig apis: 490 and len adversarial apis: 502
#   [!] Model scores on          this sample -- logit: 77.6996  and probability: 1.0000
#   [!] Iteration 13
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 74.0753  and probability: 1.0000
#   [!] Iteration 14
#   [!] Len orig apis: 490 and len adversarial apis: 504
#   [!] Model scores on          this sample -- logit: 77.6878  and probability: 1.0000
#   [!] Iteration 15
#   [!] Len orig apis: 490 and len adversarial apis: 505
#   [!] Model scores on          this sample -- logit: 77.4759  and probability: 1.0000
#   [!] Iteration 16
#   [!] Len orig apis: 490 and len adversarial apis: 506
#   [!] Model scores on          this sample -- logit: 79.6463  and probability: 1.0000
#   [!] Iteration 17
#   [!] Len orig apis: 490 and len adversarial apis: 507
#   [!] Model scores on          this sample -- logit: 85.3438  and probability: 1.0000
#   [!] Iteration 18
#   [!] Len orig apis: 490 and len adversarial apis: 508
#   [!] Model scores on          this sample -- logit: 85.0391  and probability: 1.0000
#   [!] Iteration 19
#   [!] Len orig apis: 490 and len adversarial apis: 509
#   [!] Model scores on          this sample -- logit: 87.9723  and probability: 1.0000

# %%
import scienceplots
plt.style.use(['science', 'no-latex'])

logits = np.array(logits_api)
# plot 
plt.figure(figsize=(10,5))
plt.plot(logits)
plt.scatter(range(0,20), logits)
plt.ylabel("Sample Logit Score", fontsize=14)
plt.xlabel("Number of benign APIs preprended", fontsize=14)
# set xlabelticks from 0 to 20 with step 1
_ = plt.xticks(np.arange(0, 20, 1))

# %% [markdown]
# ### Pre-pending legitimate APIs from benign samples

# %%
benign_folder = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_windows_syswow64")

from collections import defaultdict
logits = defaultdict(list)
for file in os.listdir(benign_folder)[:30]:
    print("\n[*] Starting with file:", file, "...")
    if not file.endswith("json"):
        continue
    with open(os.path.join(benign_folder, file)) as f:
        benign = json.load(f)

    for i in [1, 2, 4, 8, 16]:
        print(f" Multiplier: {i}")
        legit_apis = deepcopy(benign[0]['apis'])
        orig_apis = deepcopy(exampleFile[0]['apis'])
        adversarial_example = deepcopy(exampleFile)
        adversarial_example[0]['apis'] = i*legit_apis + orig_apis
        print(f"  [!] Len orig apis: {len(orig_apis)} and len adversarial apis: {len(adversarial_example[0]['apis'])}")

        l = get_score(adversarial_example)
        logits[i].append(l)
# Out:
# [*] Starting with file: agentactivationruntimestarter.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 67.6285  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 71.3066  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 69.8146  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 70.1237  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 70.1237  and probability: 1.0000
#
# [*] Starting with file: appidtel.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 85.4789  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 110.1476 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 130.5715 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 130.5715 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 130.5715 and probability: 1.0000
#
# [*] Starting with file: AppVDllSurrogate.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 497
#   [!] Model scores on          this sample -- logit: 78.7684  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 504
#   [!] Model scores on          this sample -- logit: 91.9380  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 518
#   [!] Model scores on          this sample -- logit: 120.8856 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 546
#   [!] Model scores on          this sample -- logit: 120.8856 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 602
#   [!] Model scores on          this sample -- logit: 120.8856 and probability: 1.0000
#
# [*] Starting with file: appverif.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 68.1865  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 69.4408  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 79.3799  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 79.3799  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 79.3799  and probability: 1.0000
#
# [*] Starting with file: AtBroker.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 502
#   [!] Model scores on          this sample -- logit: 79.4391  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 514
#   [!] Model scores on          this sample -- logit: 101.1095 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 538
#   [!] Model scores on          this sample -- logit: 115.9524 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 586
#   [!] Model scores on          this sample -- logit: 115.9524 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 682
#   [!] Model scores on          this sample -- logit: 115.9524 and probability: 1.0000
#
# [*] Starting with file: attrib.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 71.0346  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 72.6146  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 74.6141  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 70.2937  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 70.2937  and probability: 1.0000
#
# [*] Starting with file: auditpol.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 68.2374  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 75.9528  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 87.7443  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 97.2780  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 97.2780  and probability: 1.0000
#
# [*] Starting with file: BackgroundTransferHost.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 68.7188  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 76.3841  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 87.9493  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 96.9633  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 96.9633  and probability: 1.0000
#
# [*] Starting with file: ByteCodeGenerator.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 497
#   [!] Model scores on          this sample -- logit: 78.3357  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 504
#   [!] Model scores on          this sample -- logit: 112.0784 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 518
#   [!] Model scores on          this sample -- logit: 136.1184 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 546
#   [!] Model scores on          this sample -- logit: 136.1184 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 602
#   [!] Model scores on          this sample -- logit: 136.1184 and probability: 1.0000
#
# [*] Starting with file: cacls.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 68.7667  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 76.7866  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 89.4639  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 99.2825  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 99.2825  and probability: 1.0000
#
# [*] Starting with file: calc.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 72.9992  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 74.0272  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 79.7035  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 92.0776  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 92.0776  and probability: 1.0000
#
# [*] Starting with file: CameraSettingsUIHost.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 499
#   [!] Model scores on          this sample -- logit: 85.5719  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 508
#   [!] Model scores on          this sample -- logit: 100.1506 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 526
#   [!] Model scores on          this sample -- logit: 125.7939 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 562
#   [!] Model scores on          this sample -- logit: 125.7939 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 634
#   [!] Model scores on          this sample -- logit: 125.7939 and probability: 1.0000
#
# [*] Starting with file: CertEnrollCtrl.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 68.5245  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 75.5576  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 86.0718  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 93.9636  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 93.9636  and probability: 1.0000
#
# [*] Starting with file: certreq.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 69.4268  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 82.1411  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 94.4928  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 104.6507 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 104.6507 and probability: 1.0000
#
# [*] Starting with file: certutil.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 74.1474  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 75.8510  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 78.1429  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 78.1429  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 78.1429  and probability: 1.0000
#
# [*] Starting with file: charmap.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 69.9138  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 79.5228  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 83.4140  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 85.3515  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 85.3515  and probability: 1.0000
#
# [*] Starting with file: CheckNetIsolation.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 66.1933  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 74.5110  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 86.9184  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 97.4503  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 97.4503  and probability: 1.0000
#
# [*] Starting with file: chkntfs.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 75.5802  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 97.9233  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 117.0121 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 117.0121 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 117.0121 and probability: 1.0000
#
# [*] Starting with file: cipher.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 508
#   [!] Model scores on          this sample -- logit: 92.7826  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 526
#   [!] Model scores on          this sample -- logit: 129.2337 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 562
#   [!] Model scores on          this sample -- logit: 129.2337 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 634
#   [!] Model scores on          this sample -- logit: 129.2337 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 778
#   [!] Model scores on          this sample -- logit: 129.2337 and probability: 1.0000
#
# [*] Starting with file: cliconfg.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 81.5374  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 100.0180 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 103.2759 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 103.2759 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 103.2759 and probability: 1.0000
#
# [*] Starting with file: clip.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 531
#   [!] Model scores on          this sample -- logit: 97.3667  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 572
#   [!] Model scores on          this sample -- logit: 97.3667  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 654
#   [!] Model scores on          this sample -- logit: 97.3667  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 818
#   [!] Model scores on          this sample -- logit: 97.3667  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 1146
#   [!] Model scores on          this sample -- logit: 97.3667  and probability: 1.0000
#
# [*] Starting with file: CloudNotifications.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 70.3624  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 79.7258  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 83.3260  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 83.6719  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 83.6719  and probability: 1.0000
#
# [*] Starting with file: cmd.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 497
#   [!] Model scores on          this sample -- logit: 80.0229  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 504
#   [!] Model scores on          this sample -- logit: 105.4490 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 518
#   [!] Model scores on          this sample -- logit: 129.2932 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 546
#   [!] Model scores on          this sample -- logit: 129.2932 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 602
#   [!] Model scores on          this sample -- logit: 129.2932 and probability: 1.0000
#
# [*] Starting with file: cmdkey.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 495
#   [!] Model scores on          this sample -- logit: 67.5724  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 500
#   [!] Model scores on          this sample -- logit: 75.8304  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 510
#   [!] Model scores on          this sample -- logit: 88.3912  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 530
#   [!] Model scores on          this sample -- logit: 99.0522  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 570
#   [!] Model scores on          this sample -- logit: 99.0522  and probability: 1.0000
#
# [*] Starting with file: cmdl32.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 67.4937  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 67.0615  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 74.7934  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 74.7934  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 74.7934  and probability: 1.0000
#
# [*] Starting with file: cmmon32.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 73.9026  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 75.7495  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 80.9278  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 80.9278  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 80.9278  and probability: 1.0000
#
# [*] Starting with file: cmstp.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 79.9669  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 81.9588  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 84.3151  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 84.3151  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 84.3151  and probability: 1.0000
#
# [*] Starting with file: colorcpl.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 80.0747  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 101.0114 and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 104.6369 and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 104.6369 and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 104.6369 and probability: 1.0000
#
# [*] Starting with file: compact.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 504
#   [!] Model scores on          this sample -- logit: 79.6009  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 518
#   [!] Model scores on          this sample -- logit: 96.2698  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 546
#   [!] Model scores on          this sample -- logit: 99.4849  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 602
#   [!] Model scores on          this sample -- logit: 99.4849  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 714
#   [!] Model scores on          this sample -- logit: 99.4849  and probability: 1.0000
#
# [*] Starting with file: control.json ...
#  Multiplier: 1
#   [!] Len orig apis: 490 and len adversarial apis: 503
#   [!] Model scores on          this sample -- logit: 44.9081  and probability: 1.0000
#  Multiplier: 2
#   [!] Len orig apis: 490 and len adversarial apis: 516
#   [!] Model scores on          this sample -- logit: 64.3924  and probability: 1.0000
#  Multiplier: 4
#   [!] Len orig apis: 490 and len adversarial apis: 542
#   [!] Model scores on          this sample -- logit: 66.3279  and probability: 1.0000
#  Multiplier: 8
#   [!] Len orig apis: 490 and len adversarial apis: 594
#   [!] Model scores on          this sample -- logit: 66.3279  and probability: 1.0000
#  Multiplier: 16
#   [!] Len orig apis: 490 and len adversarial apis: 698
#   [!] Model scores on          this sample -- logit: 66.3279  and probability: 1.0000

# %%
#logits[0] = [75.9193]
try:
    del logits[0]
except:
    pass
x = sorted(list(logits.keys()))
y = [np.mean(logits[k]) for k in x]
yerr = [np.std(logits[k]) for k in x]
plt.figure(figsize=(10,5))
# add errorbars with borders
plt.errorbar(x, y, yerr=yerr, fmt='o', capthick=2, capsize=10, color="black")
# add line with the same color as above
plt.plot(x, y, color='black')
plt.xscale('log')
plt.xlabel("Multiplier of benign APIs injection", fontsize=14)
plt.ylabel("Maliciousness Logit Score", fontsize=14)
# xticks and xlabels 1,2,4,8,16
_ = plt.xticks([1,2,4,8,16], [1,2,4,8,16])

# %% [markdown]
# ## File access modifications
#
# Just remove file modifications:

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

adversarial_example = deepcopy(exampleFile)
adversarial_example[0]["file_access"] = []

random_seed = 1492
set_random_seed(random_seed)
model = TransformerEncoderChunks(**model_config).to(DEVICE)
model.load_state_dict(state_dict)
model.eval()
extractor = PEDynamicFeatureExtractor()
exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

exampleTokenized = tokenizer.tokenize(exampleProcessed)
if len(exampleTokenized) == 1:
    exampleTokenized = exampleTokenized[0]
exampleEncoded = tokenizer.encode(exampleProcessed)
x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

logit_bad = model(x[:, :512]).cpu()
prob_bad = torch.sigmoid(logit_bad)
print("  [ ] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
#   [ ] Model scores on this sample -- logit: -2.192409  and probability: 0.100434236

# %% [markdown]
# ## Inject legitimate file activities

# %%
from pprint import pprint
benign_folder = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_clean")
# cd /mnt/c/Users/dtrizna/Code/nebula/data/data_raw/windows_emulation_trainset/report_clean
# grep -rn . -ie "file_ac"
file_examples = ["0004c0ff7776dea5d0297fe8097813c98da7c490c7e6ddb60214c067777621b2.json", 
                 "0008ac09c36a9d430ed9639165a0dcd714878573bed032548246bb5d77b63eff.json",
                 "./000c81a10306c4ecaf17ad7a56543a555de0c2b1b51c6ef64927a1da34676b9a.json",
                 "./0029db52469940e64c9755dd7b5794e889ea54dc9a59dd01d663f59ef4087523.json"]

for example in file_examples:
    with open(os.path.join(benign_folder, example)) as f:
        benign = json.load(f)
    
    print("\n[!] Injecting this sample's file manipulations:")
    print("\t", benign[0]['file_access'])

    adversarial_example = deepcopy(exampleFile)
    orig_file_access = deepcopy(adversarial_example[0]["file_access"])
    adversarial_example[0]["file_access"] = deepcopy(benign[0]['file_access']) + orig_file_access

    random_seed = 1492
    set_random_seed(random_seed)
    model = TransformerEncoderChunks(**model_config).to(DEVICE)
    model.load_state_dict(state_dict)
    model.eval()
    extractor = PEDynamicFeatureExtractor()
    exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

    exampleTokenized = tokenizer.tokenize(exampleProcessed)
    if len(exampleTokenized) == 1:
        exampleTokenized = exampleTokenized[0]
    exampleEncoded = tokenizer.encode(exampleProcessed)
    x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

    logit_bad = model(x[:, :512]).cpu()
    prob_bad = torch.sigmoid(logit_bad)
    
    print("  [>] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
# [!] Injecting this sample's file manipulations:
# 	 [{'event': 'open', 'path': 'C:\\Windows\\system32\\0004c0ff7776dea5d0297fe8097813c98da7c490c7e6ddb60214c067777621b2', 'open_flags': ['OPEN_EXISTING']}]
#   [>] Model scores on this sample -- logit: 72.49878  and probability: 1.0
#
# [!] Injecting this sample's file manipulations:
# 	 [{'event': 'open', 'path': 'C:\\Windows\\system32\\0008ac09c36a9d430ed9639165a0dcd714878573bed032548246bb5d77b63eff', 'open_flags': ['OPEN_EXISTING'], 'access_flags': ['GENERIC_READ']}, {'event': 'read', 'path': 'C:\\Windows\\system32\\0008ac09c36a9d430ed9639165a0dcd714878573bed032548246bb5d77b63eff', 'size': 1542, 'buffer': '0x1210a34'}]
#   [>] Model scores on this sample -- logit: 74.30383  and probability: 1.0
#
# [!] Injecting this sample's file manipulations:
# 	 [{'event': 'create', 'path': '㩃停潲牧浡䘠汩獥\\GUT_1646332290.tmp', 'open_flags': ['OPEN_ALWAYS'], 'access_flags': ['GENERIC_READ', 'GENERIC_WRITE']}]
#   [>] Model scores on this sample -- logit: 72.744736  and probability: 1.0
#
# [!] Injecting this sample's file manipulations:
# 	 [{'event': 'create', 'path': 'Google\\Temp\\GUT_1646350089.tmp', 'open_flags': ['OPEN_ALWAYS'], 'access_flags': ['GENERIC_READ', 'GENERIC_WRITE']}]
#   [>] Model scores on this sample -- logit: 72.51511  and probability: 1.0

# %% [markdown]
# ### Change filename to some legitimately looking
#
# From `C:\\Windows\\temp\\golfini.ini` to `C:\\Windows\\temp\\mssvc.ini`

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

adversarial_example = deepcopy(exampleFile)

for i, access in enumerate(adversarial_example[0]["file_access"]):
    path = access['path']
    # get only filename
    filename = os.path.basename(path)
    # replace filename with mssvc.ini
    path = path.replace(filename, "mssvc.ini")
    
    access['path'] = path
    adversarial_example[0]["file_access"][i] = access

random_seed = 1492
set_random_seed(random_seed)
model = TransformerEncoderChunks(**model_config).to(DEVICE)
model.load_state_dict(state_dict)
model.eval()
extractor = PEDynamicFeatureExtractor()
exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

exampleTokenized = tokenizer.tokenize(exampleProcessed)
if len(exampleTokenized) == 1:
    exampleTokenized = exampleTokenized[0]
exampleEncoded = tokenizer.encode(exampleProcessed)
x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

logit_bad = model(x[:, :512]).cpu()
prob_bad = torch.sigmoid(logit_bad)
print("  [ ] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
#   [ ] Model scores on this sample -- logit: 75.8184  and probability: 1.0

# %% [markdown]
# ### The same, although not changing filename, but filepath:

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

adversarial_example = deepcopy(exampleFile)

for i, access in enumerate(adversarial_example[0]["file_access"]):
    path = access['path']
    # get only base filepath
    dirname = os.path.dirname(path)
    # replace filename with mssvc.ini
    print("\n\t Old path: ", path)
    path = path.replace(dirname, "C:\\User\\user\\AppData\\Temp")
    print("\t New path: ", path)

    access['path'] = path
    adversarial_example[0]["file_access"][i] = access

random_seed = 1492
set_random_seed(random_seed)
model = TransformerEncoderChunks(**model_config).to(DEVICE)
model.load_state_dict(state_dict)
model.eval()
extractor = PEDynamicFeatureExtractor()
exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

exampleTokenized = tokenizer.tokenize(exampleProcessed)
if len(exampleTokenized) == 1:
    exampleTokenized = exampleTokenized[0]
exampleEncoded = tokenizer.encode(exampleProcessed)
x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

logit_bad = model(x[:, :512]).cpu()
prob_bad = torch.sigmoid(logit_bad)
print("  [ ] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Temp\golfinfo.ini
#
# 	 Old path:  C:\Windows\temp\golfset.ini
# 	 New path:  C:\User\user\AppData\Temp\golfset.ini
#
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Temp\golfinfo.ini
#
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Temp\golfinfo.ini
#
# 	 Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 New path:  C:\User\user\AppData\Temp\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
#
# 	 Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 New path:  C:\User\user\AppData\Temp\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
#
# 	 Old path:  Cd.exedows\temp\HGDraw.dll
# 	 New path:  C:\User\user\AppData\Temp\HGDraw.dll
#
# 	 Old path:  Cd.exedows\temp\HGDraw.dll
# 	 New path:  C:\User\user\AppData\Temp\HGDraw.dll
#   [ ] Model scores on this sample -- logit: 75.007706  and probability: 1.0

# %% [markdown]
# ### Change folder and filename, but not extension

# %%
import random
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

adversarial_example = deepcopy(exampleFile)

for i, access in enumerate(adversarial_example[0]["file_access"]):
    path = access['path']
    # get only base filepath
    dirname = os.path.dirname(path)
    filename = os.path.basename(path)
    
    print("\n\t Old path: ", path)
    # replace filepath
    path = path.replace(dirname, "C:\\User\\user\\AppData\\Google\\Temp")
    # replace filename, but keep extension the same
    if len(filename.split(".")) > 1:
        random_digits = str(random.randint(1000000000, 9999999999))
        path = path.replace(".".join(filename.split(".")[:-1]), f"GUT_{random_digits}")
    else:
        path = path.replace(filename, "GUT_1646350089.tmp")

    
    print("\t New path: ", path)

    access['path'] = path
    adversarial_example[0]["file_access"][i] = access

random_seed = 1492
set_random_seed(random_seed)
model = TransformerEncoderChunks(**model_config).to(DEVICE)
model.load_state_dict(state_dict)
model.eval()
extractor = PEDynamicFeatureExtractor()
exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

exampleTokenized = tokenizer.tokenize(exampleProcessed)
if len(exampleTokenized) == 1:
    exampleTokenized = exampleTokenized[0]
exampleEncoded = tokenizer.encode(exampleProcessed)
x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

logit_bad = model(x[:, :512]).cpu()
prob_bad = torch.sigmoid(logit_bad)
print("\n  [ ] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_5874340920.ini
#
# 	 Old path:  C:\Windows\temp\golfset.ini
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_5362635507.ini
#
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_4864273179.ini
#
# 	 Old path:  C:\Windows\temp\golfinfo.ini
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_8377265524.ini
#
# 	 Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_1646350089.tmp
#
# 	 Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_1646350089.tmp
#
# 	 Old path:  Cd.exedows\temp\HGDraw.dll
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_6149899137.dll
#
# 	 Old path:  Cd.exedows\temp\HGDraw.dll
# 	 New path:  C:\User\user\AppData\Google\Temp\GUT_4602574620.dll
#
#   [ ] Model scores on this sample -- logit: 10.040198  and probability: 0.99995637

# %% [markdown]
# ### Avoid dropping DLLs

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")
exampleFile = os.path.join(report_root, "0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json")
with open(exampleFile) as f:
    exampleFile = json.load(f)

adversarial_example = deepcopy(exampleFile)

for i, access in enumerate(adversarial_example[0]["file_access"]):
    path = access['path']
    access['path'] = path
    adversarial_example[0]["file_access"][i] = access

random_seed = 1492
set_random_seed(random_seed)
model = TransformerEncoderChunks(**model_config).to(DEVICE)
model.load_state_dict(state_dict)
model.eval()
extractor = PEDynamicFeatureExtractor()
exampleProcessed = extractor.filter_and_normalize_report(adversarial_example)

exampleTokenized = tokenizer.tokenize(exampleProcessed)
if len(exampleTokenized) == 1:
    exampleTokenized = exampleTokenized[0]
exampleEncoded = tokenizer.encode(exampleProcessed)
x = torch.Tensor(exampleEncoded).long().reshape(1,-1).to(DEVICE)

logit_bad = model(x[:, :512]).cpu()
prob_bad = torch.sigmoid(logit_bad)
print("  [ ] Model scores on this sample -- logit:", logit_bad[0][0].numpy(), " and probability:", prob_bad[0][0].numpy())
# Out:
#   [ ] Model scores on this sample -- logit: 35.266155  and probability: 1.0

# %% [markdown]
# ### Statistical analysis of file modifications

# %%
report_root = os.path.join(ROOT, r"data\data_raw\windows_emulation_trainset\report_backdoor")

has_file_access = []
LIMIT = 500
for file in tqdm(os.listdir(report_root)[:LIMIT]):
    if not file.endswith(".json"):
        continue
    with open(os.path.join(report_root, file)) as f:
        file_raw = json.load(f)
    if [x for x in file_raw if "file_access" in x]:
        #print("[!] Found file_access in: ", file)
        has_file_access.append((os.path.join(report_root, file), file_raw))
# Out:
# 100%|██████████| 500/500 [00:00<00:00, 537.70it/s]

# %%
len(has_file_access)
# Out:
# 266

# %%
import random
import string
def change_folder(path, new_folder):
    # get only base filepath
    dirname = os.path.dirname(path)
    
    # replace filepath
    path = path.replace(dirname, "C:\\User\\user\\AppData\\Google\\Temp")
    # replace filename, but keep extension the same
    return path

def change_filename(path, new_filename):
    filename = os.path.basename(path)
    if len(filename.split(".")) > 1:
        # leave extension
        filename = ".".join(filename.split(".")[:-1])        
    path = path.replace(filename, new_filename)
    return path


results = defaultdict(list)
LIMIT = None
for file_name, file_content in has_file_access[0:LIMIT]:
    print('\n[!!!] Processing file: ', file_name)
    results['No modifications'].append(get_score(file_content))

    # change file directories to appdata/google and get score
    print("  [*] Running modificaitons with file folder change to Google's Temp...")
    adversarial_example = deepcopy(file_content)
    for entry in adversarial_example:
        if "file_access" in entry:
            for i, access in enumerate(entry["file_access"]):
                print(f"\t [{i}] Old path: ", access['path'])
                access['path'] = change_folder(access['path'], "C:\\User\\user\\AppData\\Google\\Temp")
                print(f"\t [{i}] New path: ", access['path'])
    results['changed_folder'].append(get_score(adversarial_example, "changed folder"))

    # change file name to legit
    print("  [*] Running modificaitons with filename change to legit one...")
    adversarial_example = deepcopy(file_content)
    for entry in adversarial_example:
        if "file_access" in entry:
            for i, access in enumerate(entry["file_access"]):
                print(f"\t [{i}] Old path: ", access['path'])
                access['path'] = change_filename(access['path'], "chrome")
                print(f"\t [{i}] New path: ", access['path'])
    results['changed_filename_(legit)'].append(get_score(adversarial_example, "changed filename"))

    # change filename to random
    print("  [*] Running modificaitons with filename change to random one...")
    adversarial_example = deepcopy(file_content)
    for entry in adversarial_example:
        if "file_access" in entry:
            for i, access in enumerate(entry["file_access"]):
                print(f"\t [{i}] Old path: ", access['path'])
                random_string = ''.join(random.choices(string.ascii_uppercase + string.digits, k=10))
                access['path'] = change_filename(access['path'], random_string)
                print(f"\t [{i}] New path: ", access['path'])
    results['changed_filename_(random)'].append(get_score(adversarial_example, "changed filename"))

    # remove all file modifications and get score
    adversarial_example = deepcopy(file_content)
    for entry in adversarial_example:
        if "file_access" in entry:
            entry["file_access"] = []
    results['file_access_avoided'].append(get_score(adversarial_example, "removed file_access"))
# Out:
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a.json
#   [!] Model scores on          this sample -- logit: 75.9193  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [4] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [4] New path:  C:\User\user\AppData\Google\Temp\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [5] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [5] New path:  C:\User\user\AppData\Google\Temp\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [6] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [6] New path:  C:\User\user\AppData\Google\Temp\HGDraw.dll
# 	 [7] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [7] New path:  C:\User\user\AppData\Google\Temp\HGDraw.dll
#   [!] Model scores on       changed folder -- logit:  5.5588  and probability: 0.9962
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\chrome.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\chrome.ini
# 	 [4] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [4] New path:  C:\Windows\system32\chrome
# 	 [5] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [5] New path:  C:\Windows\system32\chrome
# 	 [6] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [6] New path:  Cd.exedows\temp\chrome.dll
# 	 [7] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [7] New path:  Cd.exedows\temp\chrome.dll
#   [!] Model scores on     changed filename -- logit: 68.4960  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\3X1A25Z563.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\M6RUXUVVC6.ini
# 	 [4] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [4] New path:  C:\Windows\system32\A86TKRYSWK
# 	 [5] Old path:  C:\Windows\system32\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a
# 	 [5] New path:  C:\Windows\system32\JEX83MXN0H
# 	 [6] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [6] New path:  Cd.exedows\temp\J6GQM8GFTH.dll
# 	 [7] Old path:  Cd.exedows\temp\HGDraw.dll
# 	 [7] New path:  Cd.exedows\temp\952V9OBXOW.dll
#   [!] Model scores on     changed filename -- logit: 75.3751  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: -2.1924  and probability: 0.1004
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\001180134ff5ae8227e97f5eb8411e5c8ef599e2500eb33916f429b4de133cc3.json
#   [!] Model scores on          this sample -- logit: 41.8438  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  \\.\C:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
# 	 [2] Old path:  \\.\PHYSICALDRIVE0
# 	 [2] New path:  C:\User\user\AppData\Google\Temp
# 	 [3] Old path:  C:\Windows\temp\golfset.ini
# 	 [3] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
# 	 [4] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [4] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [5] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [5] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [6] Old path:  C:\Windows\system32\001180134ff5ae8227e97f5eb8411e5c8ef599e2500eb33916f429b4de133cc3
# 	 [6] New path:  C:\User\user\AppData\Google\Temp\001180134ff5ae8227e97f5eb8411e5c8ef599e2500eb33916f429b4de133cc3
# 	 [7] Old path:  C:\Windows\system32\001180134ff5ae8227e97f5eb8411e5c8ef599e2500eb33916f429b4de133cc3
# 	 [7] New path:  C:\User\user\AppData\Google\Temp\001180134ff5ae8227e97f5eb8411e5c8ef599e2500eb33916f429b4de133cc3
#   [!] Model scores on       changed folder -- logit:  0.9037  and probability: 0.7117
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp
Old path:  C:\Windows\temp\golfinfo.ini
# 	 [4] New path:  C:\Windows\temp\A86TKRYSWK.ini
# 	 [5] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [5] New path:  C:\Windows\temp\JEX83MXN0H.ini
# 	 [6] Old path:  C:\Windows\system32\002a878755f82b7e2e04fabc845438718df3cfab04429202abb37b801e4526b4
# 	 [6] New path:  C:\Windows\system32\J6GQM8GFTH
# 	 [7] Old path:  C:\Windows\system32\002a878755f82b7e2e04fabc845438718df3cfab04429202abb37b801e4526b4
# 	 [7] New path:  C:\Windows\system32\952V9OBXOW
#   [!] Model scores on     changed filename -- logit: 31.8711  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: -0.4370  and probability: 0.3925
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129.json
#   [!] Model scores on          this sample -- logit: 35.1923  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [4] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [4] New path:  C:\User\user\AppData\Google\Temp\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [5] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [5] New path:  C:\User\user\AppData\Google\Temp\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
#   [!] Model scores on       changed folder -- logit: -3.6663  and probability: 0.0249
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\chrome.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\chrome.ini
# 	 [4] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [4] New path:  C:\Windows\system32\chrome
# 	 [5] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [5] New path:  C:\Windows\system32\chrome
#   [!] Model scores on     changed filename -- logit: 28.0588  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\3X1A25Z563.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\M6RUXUVVC6.ini
# 	 [4] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [4] New path:  C:\Windows\system32\A86TKRYSWK
# 	 [5] Old path:  C:\Windows\system32\002ff34698cb96c978e64615adc2aea4abef6a2e85e1dee5d46968db5d215129
# 	 [5] New path:  C:\Windows\system32\JEX83MXN0H
#   [!] Model scores on     changed filename -- logit: 49.8262  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit:  0.7603  and probability: 0.6814
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\003fc601deea88cf2cc197d30d27345fccc97b830825ae4974f6b2b086bc19fa.json
#   [!] Model scores on          this sample -- logit:  3.3440  and probability: 0.9659
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  3.1463  and probability: 0.9588
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  7.0351  and probability: 0.9991
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit: 14.6443  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit:  1.9651  and probability: 0.8771
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0057e47169efa012111ab25e83c36b77e8f470fc9d094bca0e0d1f86541a6f90.json
#   [!] Model scores on          this sample -- logit:  6.9214  and probability: 0.9990
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  6.2352  and probability: 0.9980
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  5.7439  and probability: 0.9968
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit:  8.4126  and probability: 0.9998
#   [!] Model scores on  removed file_access -- logit: 15.8486  and probability: 1.0000
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0062c46371328306ac7aed15be7a1d2157827099df6d5b70f74f8c0918764d37.json
#   [!] Model scores on          this sample -- logit:  8.3501  and probability: 0.9998
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  7.9871  and probability: 0.9997
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  6.5027  and probability: 0.9985
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit: 11.7718  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: 10.0445  and probability: 1.0000
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\006451e48042f500cbca6395c797dbec4b35355ad25482748377cd96289027ce.json
#   [!] Model scores on          this sample -- logit:  2.2694  and probability: 0.9063
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  4.2303  and probability: 0.9857
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit: -3.0235  and probability: 0.0464
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit:  7.2065  and probability: 0.9993
#   [!] Model scores on  removed file_access -- logit:  7.3139  and probability: 0.9993
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\006acb9c0332a56d366378f70444464cc8b7b139eed11cd6ad6990b4d9d9731a.json
#   [!] Model scores on          this sample -- logit: 23.6239  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
#   [!] Model scores on       changed folder -- logit: -1.0833  and probability: 0.2529
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
#   [!] Model scores on     changed filename -- logit: 25.2058  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
#   [!] Model scores on     changed filename -- logit: 29.5089  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: -1.0552  and probability: 0.2582
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70.json
#   [!] Model scores on          this sample -- logit: 67.3566  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  \\.\C:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
# 	 [2] Old path:  \\.\PHYSICALDRIVE0
# 	 [2] New path:  C:\User\user\AppData\Google\Temp
# 	 [3] Old path:  C:\Windows\temp\golfset.ini
# 	 [3] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
# 	 [4] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [4] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [5] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [5] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [6] Old path:  C:\Windows\system32\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [6] New path:  C:\User\user\AppData\Google\Temp\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [7] Old path:  C:\Windows\system32\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [7] New path:  C:\User\user\AppData\Google\Temp\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [8] Old path:  Cb.exedows\temp\HGDraw.dll
# 	 [8] New path:  C:\User\user\AppData\Google\Temp\HGDraw.dll
# 	 [9] Old path:  Cb.exedows\temp\HGDraw.dll
# 	 [9] New path:  C:\User\user\AppData\Google\Temp\HGDraw.dll
# 	 [10] Old path:  C:\Windows\temp\sanfdr.bat
# 	 [10] New path:  C:\User\user\AppData\Google\Temp\sanfdr.bat
# 	 [11] Old path:  C:\Windows\temp\sanfdr.bat
# 	 [11] New path:  C:\User\user\AppData\Google\Temp\sanfdr.bat
#   [!] Model scores on       changed folder -- logit: -13.3147 and probability: 0.0000
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  \\.\C:
# 	 [1] New path:  chrome\chrome\chrome.chrome\chromeCchrome:chrome
# 	 [2] Old path:  \\.\PHYSICALDRIVE0
# 	 [2] New path:  chrome\chrome\chrome.chrome\chromePchromeHchromeYchromeSchromeIchromeCchromeAchromeLchromeDchromeRchromeIchromeVchromeEchrome0chrome
# 	 [3] Old path:  C:\Windows\temp\golfset.ini
# 	 [3] New path:  C:\Windows\temp\chrome.ini
# 	 [4] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [4] New path:  C:\Windows\temp\chrome.ini
# 	 [5] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [5] New path:  C:\Windows\temp\chrome.ini
# 	 [6] Old path:  C:\Windows\system32\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [6] New path:  C:\Windows\system32\chrome
# 	 [7] Old path:  C:\Windows\system32\006cae5159480d2deea3156d976bcbee5fca69d321d29be036a536111c0b3d70
# 	 [7] New path:  C:\Windows\system32\chrome
# 	 [8] Old path:  Cb.exedows\temp\HGDraw.dll
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\00a55c25ca913c92e5af2cff5c20dd1300d2a999e1bfed25c68eaca459f75f2e.json
#   [!] Model scores on          this sample -- logit:  4.3659  and probability: 0.9875
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  2.9033  and probability: 0.9480
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  8.0043  and probability: 0.9997
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit: 13.2420  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit:  4.4691  and probability: 0.9887
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\00b6344097b69e1e2112cb61accc280ad888e1c92413c575718e91542b1c2a95.json
#   [!] Model scores on          this sample -- logit:  8.3034  and probability: 0.9998
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  8.7332  and probability: 0.9998
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  9.2621  and probability: 0.9999
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit: 10.6799  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: 17.1270  and probability: 1.0000
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37.json
#   [!] Model scores on          this sample -- logit: 43.7205  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [4] Old path:  C:\Windows\system32\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
# 	 [4] New path:  C:\User\user\AppData\Google\Temp\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
# 	 [5] Old path:  C:\Windows\system32\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
# 	 [5] New path:  C:\User\user\AppData\Google\Temp\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
#   [!] Model scores on       changed folder -- logit:  4.4889  and probability: 0.9889
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\chrome.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\chrome.ini
# 	 [4] Old path:  C:\Windows\system32\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
# 	 [4] New path:  C:\Windows\system32\chrome
# 	 [5] Old path:  C:\Windows\system32\00b7254355518efbcd5b7a1a8e40fd75a9f1cc581f4fd46f7d3f3514e4058b37
# 	 [5] New path:  C:\Windows\system32\chrome
#   [!] Model scores on     changed filename -- logit: 35.8210  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:
ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
# 	 [2] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [2] New path:  C:\Windows\temp\3X1A25Z563.ini
# 	 [3] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [3] New path:  C:\Windows\temp\M6RUXUVVC6.ini
# 	 [4] Old path:  C:\Windows\system32\0a6eb8b1677388b0ba9b28eb3606291e2008db921f815ffb508a0b5a51a0be3d
# 	 [4] New path:  C:\Windows\system32\A86TKRYSWK
# 	 [5] Old path:  C:\Windows\system32\0a6eb8b1677388b0ba9b28eb3606291e2008db921f815ffb508a0b5a51a0be3d
# 	 [5] New path:  C:\Windows\system32\JEX83MXN0H
#   [!] Model scores on     changed filename -- logit: 61.0300  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit:  4.3907  and probability: 0.9878
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0a72cbdf9e50acaebe98f561f3087101cdedf94f43548602ad96aef942c44e6c.json
#   [!] Model scores on          this sample -- logit:  4.3178  and probability: 0.9868
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  5.9319  and probability: 0.9974
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  4.9577  and probability: 0.9930
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit:  8.6320  and probability: 0.9998
#   [!] Model scores on  removed file_access -- logit: 13.9416  and probability: 1.0000
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0a841970c51ec2a64b704bd9a64e523beeafeb4378b31b049a6702bd8db44c5b.json
#   [!] Model scores on          this sample -- logit: 20.6627  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
#   [!] Model scores on       changed folder -- logit: -3.3316  and probability: 0.0345
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
#   [!] Model scores on     changed filename -- logit: 22.2272  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
#   [!] Model scores on     changed filename -- logit: 24.3232  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: -4.0946  and probability: 0.0164
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0a8823261328e2c8c332e182e02773c2b74260841b333ac22df40b106b346eea.json
#   [!] Model scores on          this sample -- logit: 25.2416  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\User\user\AppData\Google\Temp\golfset.ini
#   [!] Model scores on       changed folder -- logit:  1.4248  and probability: 0.8061
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\chrome.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\chrome.ini
#   [!] Model scores on     changed filename -- logit: 27.4638  and probability: 1.0000
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\Windows\temp\6E3KBAKIP0.ini
# 	 [1] Old path:  C:\Windows\temp\golfset.ini
# 	 [1] New path:  C:\Windows\temp\6ZYH4RSO5E.ini
#   [!] Model scores on     changed filename -- logit: 33.8413  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit:  2.1720  and probability: 0.8977
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0ab24c056ab23f9f566baf769f7c756d040dd645236aeff158b4e62bb2ff5696.json
#   [!] Model scores on          this sample -- logit: 41.2742  and probability: 1.0000
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [0] New path:  C:\User\user\AppData\Google\Temp\golfinfo.ini
# 	 
Old path:  C:\Windows\temp\golfinfo.ini
# 	 [4] New path:  C:\Windows\temp\A86TKRYSWK.ini
# 	 [5] Old path:  C:\Windows\temp\golfinfo.ini
# 	 [5] New path:  C:\Windows\temp\JEX83MXN0H.ini
# 	 [6] Old path:  C:\Windows\system32\0ab24c056ab23f9f566baf769f7c756d040dd645236aeff158b4e62bb2ff5696
# 	 [6] New path:  C:\Windows\system32\J6GQM8GFTH
# 	 [7] Old path:  C:\Windows\system32\0ab24c056ab23f9f566baf769f7c756d040dd645236aeff158b4e62bb2ff5696
# 	 [7] New path:  C:\Windows\system32\952V9OBXOW
#   [!] Model scores on     changed filename -- logit: 24.4185  and probability: 1.0000
#   [!] Model scores on  removed file_access -- logit: 10.1615  and probability: 1.0000
#
# [!!!] Processing file:  C:\Users\dtrizna\Code\nebula\evaluation\adversarial\..\..\data\data_raw\windows_emulation_trainset\report_backdoor\0ab701925355db7dfd387146e07f6abff893b7e60a53f3d5a17428794f492647.json
#   [!] Model scores on          this sample -- logit:  4.9661  and probability: 0.9931
#   [*] Running modificaitons with file folder change to Google's Temp...
# 	 [0] Old path:
# 	 [0] New path:  C:\User\user\AppData\Google\Temp
# 	 [1] Old path:
# 	 [1] New path:  C:\User\user\AppData\Google\Temp
#   [!] Model scores on       changed folder -- logit:  5.3811  and probability: 0.9954
#   [*] Running modificaitons with filename change to legit one...
# 	 [0] Old path:
# 	 [0] New path:  chrome
# 	 [1] Old path:
# 	 [1] New path:  chrome
#   [!] Model scores on     changed filename -- logit:  7.2775  and probability: 0.9993
#   [*] Running modificaitons with filename change to random one...
# 	 [0] Old path:
# 	 [0] New path:  6E3KBAKIP0
# 	 [1] Old path:
# 	 [1] New path:  6ZYH4RSO5E
#   [!] Model scores on     changed filename -- logit:  7.9989  and probability: 0.9997
#   [!] Model scores on  removed file_access -- logit:  3.8620  and probability: 0.9794

# %%
import scienceplots
plt.style.use(['science', 'no-latex'])

# logit results
x = results.keys()
y = {}
yerr = {}
for k in results.keys():
    y[k] = np.mean(results[k])
    yerr[k] = np.std(results[k])

def sigmoid(i):
    return 1 / (1 + np.exp(-i))

# barplot of results with caption on err bars and bars the same color as bars
plt.figure(figsize=(14,5))
# default mild blue color
x = [" ".join(v.split("_")).capitalize() for v in x]
color='#8da0cb'
# make ecolor darker
ecolor = '#5e81b5'
# plot barplot with bold error bars
plt.bar(x, y.values(), yerr=yerr.values(), capsize=10, ecolor=ecolor, color=color, error_kw={'elinewidth': 2})
# increase font of xticks and rotate by 45 degrees
plt.xticks(fontsize=12, rotation=10)
plt.xlabel("Adversarial modification", fontsize=16)
plt.ylabel("Logits", fontsize=16)
# plot line at 0 horizontal
plt.axhline(y=0, color='black', linewidth=1)


# evasion results
evasive = {}
for k in results:
    evasive[k] = 0
    for logit in results[k]:
        prob = sigmoid(logit)
        # ember threshold
        emb_threshold = 0.833
        if prob < emb_threshold:
            evasive[k] += 1
    evasive[k] = evasive[k] / len(results[k])

# add second y axis on the right and plot evasion results with dashed red line
ax2 = plt.gca().twinx()
ax2.plot(x, evasive.values(), color='red', linestyle='dashed', marker='.', markersize=10)
#ax2.set_ylabel("Evasion rate", fontsize=16)
ax2.set_ylim([-0.5,1])

plt.legend(["Evasion rate"], loc='upper center', fontsize=16)

plt.savefig("file_access_attacks.png", dpi=300, bbox_inches='tight')
