# %%
import copy
import json
import os
import pathlib
import sys

import matplotlib.pyplot as plt
import numpy as np

# shap displays NumbaDeprecationWarning when importing -- supress them
import warnings
from numba.core.errors import NumbaDeprecationWarning
warnings.filterwarnings("ignore", category=NumbaDeprecationWarning)

import shap
import torch
from torch import Tensor, sigmoid

# logging.basicConfig(level=logging.INFO)

# correct path to repository root
if os.path.basename(os.getcwd()) == "scripts":
    REPOSITORY_ROOT = os.path.join(os.getcwd(), "..")
elif os.path.basename(os.getcwd()) == "adversarial":
    REPOSITORY_ROOT = os.path.join(os.getcwd(), "..", "..")
else:
    REPOSITORY_ROOT = os.getcwd()
sys.path.append(REPOSITORY_ROOT)

from nebula import PEDynamicFeatureExtractor
from nebula.models.attention import TransformerEncoderOptionalEmbedding
from nebula.preprocessing import JSONTokenizerNaive

from nebula.misc import fix_random_seed
fix_random_seed(0)


def compute_score(llm, x, verbose=True):
    logit = llm(x)
    prob = sigmoid(logit)
    if verbose:
        print(f"\n[!!!] Probability of being malicious: {prob.item():.3f} | Logit: {logit.item():.3f}")
    return prob.item()


def load_tokenizer():
    with open(os.path.join(REPOSITORY_ROOT, "nebula", "objects",
                           "speakeasy_whitespace_50000_vocab.json")) as f:
        vocab = json.load(f)

    tokenizer = JSONTokenizerNaive(
        vocab_size=len(vocab),
        seq_len=512,
        vocab=vocab
    )
    return tokenizer

def tokenize_sample(report_path, encode=True):
    extractor = PEDynamicFeatureExtractor()
    filtered_report = extractor.filter_and_normalize_report(report_path)
    tokenizer = load_tokenizer()
    tokenized_report = tokenizer.tokenize(filtered_report)
    if encode:
        encoded_report = tokenizer.encode(tokenized_report, pad=True, tokenize=False)
        x = Tensor(encoded_report).long()
        return x
    else:
        return tokenized_report


def embed(llm_model, report, device="cpu"):
    src = tokenize_sample(report)
    s = llm_model.split(src)
    s = s.to(device)
    e = llm_model.embed(s)
    return e


def plot_shap_values(shap_values: np.ndarray, name: str):
    shap_values = shap_values.mean(axis=2)
    pos_idx = shap_values[0] >= 0
    neg_index = shap_values[0] < 0
    pos_shap = copy.deepcopy(shap_values)[0]
    pos_shap[neg_index] = 0
    neg_shap = copy.deepcopy(shap_values)[0]
    neg_shap[pos_idx] = 0
    x = range(512)
    plt.bar(x, pos_shap)
    plt.bar(x, neg_shap)
    plt.title(name)
    plt.show()


def load_model(skip_embedding=False):
    pretrained_model = os.path.join(REPOSITORY_ROOT, "nebula", "objects", "speakeasy_whitespace_50000_torch.model")
    with open(os.path.join(REPOSITORY_ROOT, "nebula", "objects", "speakeasy_whitespace_50000_vocab.json")) as f:
        vocab = json.load(f)
    model_config = {
        "vocab_size": len(vocab),
        "maxlen": 512,
        "chunk_size": 64,  # input splitting to chunks
        "dModel": 64,  # embedding & transformer dimension
        "nHeads": 8,  # number of heads in nn.MultiheadAttention
        "dHidden": 256,  # dimension of the feedforward network model in nn.TransformerEncoder
        "nLayers": 2,  # number of nn.TransformerEncoderLayer in nn.TransformerEncoder
        "numClasses": 1,  # binary classification
        "hiddenNeurons": [64],  # classifier ffnn dims
        "layerNorm": False,
        "dropout": 0.3,
        "mean_over_sequence": False,
        "norm_first": True,
        "skip_embedding": skip_embedding
    }
    state_dict = torch.load(pretrained_model, map_location='cpu')
    llm = TransformerEncoderOptionalEmbedding(**model_config)
    llm.load_state_dict(state_dict)
    llm.eval()
    return llm


def analyse_folder(folder: pathlib.Path, llm_model, embed_baseline, name, plot=True, verbose=True):
    filepaths = []
    explanations_arr = []
    for i, report in enumerate(folder.glob("*.json")):
        print(report.name)
        x_embed = embed(llm_model, str(report))
        prob = compute_score(llm_model, x_embed, verbose=verbose)
        explainer = shap.GradientExplainer(model_no_embed, data=embed_baseline)
        explanations = explainer.shap_values(x_embed, nsamples=50)
        if plot:
            plot_shap_values(explanations, f"{name}_{i} : {prob:.3f}")
        explanations_arr.append(explanations)
        filepaths.append(report.name)
    return filepaths, explanations_arr

model = load_model()
model_no_embed = load_model(skip_embedding=True)

malware_folder = pathlib.Path(os.path.join(REPOSITORY_ROOT, "evaluation", "explanation", "malware"))
goodware_folder = pathlib.Path(os.path.join(REPOSITORY_ROOT, "evaluation", "explanation", "goodware"))

baseline_report = os.path.join(REPOSITORY_ROOT, r"emulation", "report_baseline.json")

# %%
tokenizer = load_tokenizer()
tokenizer.vocab
# Out:
# {'<pad>': 0,
#  '<unk>': 1,
#  '<mask>': 2,
#  'apiname': 3,
#  'args': 4,
#  'retval': 5,
#  '0x0': 6,
#  '0x1': 7,
#  'kernel32getprocaddress': 8,
#  '0x1000': 9,
#  'none': 10,
#  '0x77000000': 11,
#  'kernel32isbadreadptr': 12,
#  '0xfa0': 13,
#  '0xfeee0001': 14,
#  'kernel32tlsgetvalue': 15,
#  'kernel32initializecriticalsectionex': 16,
#  'kernel32flsgetvalue': 17,
#  'kernel32heapalloc': 18,
#  '0x100': 19,
#  'kernel32leavecriticalsection': 20,
#  'kernel32entercriticalsection': 21,
#  'kernel32getlasterror': 22,
#  '0x46f0': 23,
#  'kernel32setlasterror': 24,
#  '0x45f0': 25,
#  'kernel32encodepointer': 26,
#  '0x46d0': 27,
#  '0x4e4': 28,
#  '0x8': 29,
#  '0x400000': 30,
#  '0x77d10000': 31,
#  'kernel32initializecriticalsectionandspincount': 32,
#  '0x10c': 33,
#  'kernel32decodepointer': 34,
#  'kernel32multibytetowidechar': 35,
#  '0xc000': 36,
#  '0x78000000': 37,
#  'kernel32dll': 38,
#  'kernel32getcpinfoexw': 39,
#  '0x243948c': 40,
#  'user32loadstringw': 41,
#  '0x4690': 42,
#  'kernel32getqueuedcompletionstatus': 43,
#  'kernel32initatomtable': 44,
#  'user32ddeclienttransaction': 45,
#  '0x2439488': 46,
#  '0x2439480': 47,
#  '0x2439484': 48,
#  'kernel32heapsize': 49,
#  '0x2': 50,
#  'kernel32heapfree': 51,
#  '0x10': 52,
#  'kernel32getmodulehandlew': 53,
#  '0x90': 54,
#  'kernel32widechartomultibyte': 55,
#  '0x4': 56,
#  'user32charnextw': 57,
#  'kernel32getfiletype': 58,
#  '0xfeee0004': 59,
#  'kernel32gettickcount': 60,
#  'kernel32initializecriticalsection': 61,
#  'kernel32getlocaleinfow': 62,
#  '0x78c00000': 63,
#  'kernel32getstdhandle': 64,
#  '0x12': 65,
#  '0x70cc': 66,
#  '0xcd': 67,
#  'kernel32interlockedincrement': 68,
#  '0x7d90': 69,
#  '0x6': 70,
#  'user32loadstringa': 71,
#  '0x200': 72,
#  '0x3': 73,
#  '0xfeee0002': 74,
#  '0xffffffff': 75,
#  '0x77e10000': 76,
#  'user32charnexta': 77,
#  '0xfeee0000': 78,
#  '0x4610': 79,
#  'kernel32getmodulehandlea': 80,
#  '0x20': 81,
#  '0x5f800000': 82,
#  'msvcrtmemcmp': 83,
#  '0x104': 84,
#  '0x41f040': 85,
#  'kernel32isdbcsleadbyte': 86,
#  '0xfeee0003': 87,
#  'kernel32lcmapstringw': 88,
#  'path': 89,
#  'event': 90,
#  'kernel32getlocaleinfoa': 91,
#  'apis': 92,
#  '0x5': 93,
#  '0xfeee0005': 94,
#  '0x7': 95,
#  '0x800': 96,
#  '0x8ad0': 97,
#  'kernel32loadlibrarya': 98,
#  'kernel32getcpinfo': 99,
#  '0x54': 100,
#  'kernel32virtualalloc': 101,
#  '0xf003': 102,
#  '0xf002': 103,
#  '0xf001': 104,
#  '0x80': 105,
#  'encodepointer': 106,
#  'kernel32lcmapstringex': 107,
#  'kernel32loadlibraryexw': 108,
#  'kernel32getcurrentthreadid': 109,
#  '0x102': 110,
#  '0x8810': 111,
#  'loadlibrarysearchsystem32': 112,
#  '0x400': 113,
#  '0x4600': 114,
#  'kernel32getstartupinfow': 115,
#  'kernel32closehandle': 116,
#  '0x40': 117,
#  '0xfeee0006': 118,
#  '0x220': 119,
#  'kernel32getprocessheap': 120,
#  '0x7000': 121,
#  'kernel32interlockeddecrement': 122,
#  '0x18': 123,
#  '0x7d91': 124,
#  '0x8000': 125,
#  '0x1c': 126,
#  'kernel32localalloc': 127,
#  'kernel32getstringtypew': 128,
#  '0x9000': 129,
#  'pageexecutereadwrite': 130,
#  '0xfeee0007': 131,
#  'kernel32isprocessorfeaturepresent': 132,
#  'kernel32queryperformancecounter': 133,
#  '0x7e70': 134,
#  'kernel32flssetvalue': 135,
#  '0x1211c98': 136,
#  'flsalloc': 137,
#  '0x14': 138,
#  'flssetvalue': 139,
#  'kernel32getacp': 140,
#  'kernel32flsalloc': 141,
#  'decodepointer': 142,
#  'kernel32sleep': 143,
#  '0x47b0': 144,
#  'pfxmmi64instructionsavailable': 145,
#  '0x3000': 146,
#  '0x7de0': 147,
#  '0x7810': 148,
#  'kernel32setunhandledexceptionfilter': 149,
#  '0x7c000000': 150,
#  'kernel32getsystemtimeasfiletime': 151,
#  '0x69000000': 152,
#  '0x7ec0': 153,
#  'kernel32getcurrentprocessid': 154,
#  '0xc': 155,
#  '0xfffffff6': 156,
#  '0xfffffff5': 157,
#  '0xfffffff4': 158,
#  'kernel32getmodulefilenamew': 159,
#  'kernel32getenvironmentstringsw': 160,
#  'kernel32getcommandlinea': 161,
#  'kernel32freeenvironmentstringsw': 162,
#  '0x7f00': 163,
#  '0x7890': 164,
#  'kernel32createfilew': 165,
#  'flsgetvalue': 166,
#  '0x4ab0': 167,
#  'kernel32writefile': 168,
#  'msvcrtbeginthreadex': 169,
#  'initializecriticalsectionex': 170,
#  '0x407840': 171,
#  'kernel32getmodulefilenamea': 172,
#  'user32loadcursorw': 173,
#  '0x1211dc0': 174,
#  '0x41de20': 175,
#  'kernel32virtualquery': 176,
#  '0x41ddd8': 177,
#  '0x4670': 178,
#  'kernel32getstartupinfoa': 179,
#  'create': 180,
#  'kernel32getcommandlinew': 181,
#  '0x1804': 182,
#  '0x12116d8': 183,
#  '0x1211918': 184,
#  '0x77f10000': 185,
#  '0x30': 186,
#  '0x2a': 187,
#  '0x1211c18': 188,
#  'cwindowstemp': 189,
#  'kernel32isvalidcodepage': 190,
#  '0xfeee0008': 191,
#  '0x1211f38': 192,
#  '0x4c42c0': 193,
#  '0x5265c14': 194,
#  '0x5f500000': 195,
#  '0xfeee0009': 196,
#  '0xfeee000a': 197,
#  '0xfeee000b': 198,
#  'cwindowssystem32': 199,
#  '0xfeee000c': 200,
#  '0xfeee000e': 201,
#  '0xfeee000d': 202,
#  '0xfeee0014': 203,
#  '0xfeee000f': 204,
#  '0xfeee0010': 205,
#  '0xfeee0015': 206,
#  '0xfeee0012': 207,
#  '0xfeee0011': 208,
#  '0xfeee0013': 209,
#  '0xfeee0016': 210,
#  '0x7910': 211,
#  '0x8af0': 212,
#  '0x8a40': 213,
#  '0x1211518': 214,
#  '0x1211e04': 215,
#  'kernel32getconsoleprocesslist': 216,
#  '0x1db10106': 217,
#  'kernel32getversion': 218,
#  '0xfeee0017': 219,
#  '0x1211748': 220,
#  '0xfeee0018': 221,
#  '0xfeee0019': 222,
#  '0x7e71': 223,
#  'openkey': 224,
#  '0x44': 225,
#  '0x4cf': 226,
#  '0x8811': 227,
#  'openexisting': 228,
#  '0xfeee001c': 229,
#  '0xfeee001a': 230,
#  '0x7d0': 231,
#  'kernel32heapcreate': 232,
#  'genericread': 233,
#  'apimswincoresynchl120': 234,
#  '0x50000': 235,
#  '0x41e218': 236,
#  'pagereadwrite': 237,
#  '0xfeee001b': 238,
#  '0x79f0': 239,
#  '0x1211958': 240,
#  'kernel32gettemppathw': 241,
#  'advapi32regopenkeyexw': 242,
#  'kernel32tlssetvalue': 243,
#  'flsfree': 244,
#  '0x80c0': 245,
#  'apimswincorefibersl111': 246,
#  'user32loadicona': 247,
#  '0xfeee001d': 248,
#  '0x9': 249,
#  '0x1211c7c': 250,
#  'kernel32tlsalloc': 251,
#  '0x1211908': 252,
#  'fileaccess': 253,
#  'lcmapstringex': 254,
#  '0x1211718': 255,
#  '0x12114b8': 256,
#  '0xfeee0071': 257,
#  '0x7de1': 258,
#  '0x7ec1': 259,
#  '0xfeee001e': 260,
#  'kernel32sethandlecount': 261,
#  '0x1211738': 262,
#  '0x4750': 263,
#  '0x41de50': 264,
#  '0x7850': 265,
#  '0xfeee001f': 266,
#  '0xfeee0020': 267,
#  '0xd': 268,
#  '0x7930': 269,
#  'kernel32setfilepointer': 270,
#  '0xfeee007e': 271,
#  '0x1211dfc': 272,
#  'kernel32getthreadlocale': 273,
#  'crtdllsprintf': 274,
#  '0x1f': 275,
#  '0xa': 276,
#  '0x700c': 277,
#  '0x198': 278,
#  '0x704c': 279,
#  '0x708c': 280,
#  'user32loadcursora': 281,
#  '0x19a': 282,
#  'user32mapvirtualkeyw': 283,
#  '0x8cc0': 284,
#  '0x4e50': 285,
#  '0x13': 286,
#  '0x7ab0': 287,
#  '0123456789abcdefghijklmnopqrstuvwxyzabcdefghijklmnopqrstuvwxyz': 288,
#  '0x64': 289,
#  '0xf0019': 290,
#  '0x32': 291,
#  '0x11': 292,
#  '0x8260': 293,
#  '0x1211758': 294,
#  '0x12112f8': 295,
#  '0x1211f64': 296,
#  'genericwrite': 297,
#  '0xfeee0021': 298,
#  'kernel32getversionexw': 299,
#  '0xfeee0022': 300,
#  'hkeylocalmachine': 301,
#  'kernel32heaprealloc': 302,
#  '0xe': 303,
#  '0xfeee0024': 304,
#  '0x1211cf8': 305,
#  '0xfeee0025': 306,
#  '0xfeee0023': 307,
#  'setdefaultdlldirectories': 308,
#  '0x1211528': 309,
#  'drivewindowssystem32sha256': 310,
#  '0x2c': 311,
#  'kernel32versetconditionmask': 312,
#  '0xfeee0027': 313,
#  '0x12119c0': 314,
#  'hkeycurrentuser': 315,
#  '0xfeee0026': 316,
#  '0x105': 317,
#  'kernel32createdirectoryw': 318,
#  '0x6781d8': 319,
#  'user32getsyscolor': 320,
#  'kernel32getversionexa': 321,
#  '0x42a190': 322,
#  '0x4c4308': 323,
#  'closehandle': 324,
#  'gdi32getstockobject': 325,
#  'exitprocess': 326,
#  '0x34': 327,
#  'kernel32lstrcmpiw': 328,
#  'kernel32virtualprotect': 329,
#  '0x1211780': 330,
#  '0x7ad0': 331,
#  '0xfeee005f': 332,
#  '0x4bd0': 333,
#  '0x4000': 334,
#  '0x41de08': 335,
#  '0x50': 336,
#  '0x1211728': 337,
#  '0xcc': 338,
#  '0x78a0': 339,
#  'kernel32lstrlenw': 340,
#  'kernel32': 341,
#  '0xfeee0028': 342,
#  'writefile': 343,
#  'google': 344,
#  '0xfeee008b': 345,
#  'user32getsystemmetrics': 346,
#  '0x53ba40': 347,
#  '0xf': 348,
#  '0x364': 349,
#  '0x1211fd8': 350,
#  '0xb': 351,
#  '0xfeee0040': 352,
#  '0x7a80': 353,
#  '0x7830': 354,
#  '0xfeee0029': 355,
#  '0x1211c90': 356,
#  'user32loadiconw': 357,
#  'loadlibrarya': 358,
#  '0xfeee0072': 359,
#  '0xfeee002a': 360,
#  'virtualalloc': 361,
#  '0x4630': 362,
#  '0x42e5b0': 363,
#  '0x7540': 364,
#  '0x1211f7c': 365,
#  '0xfeee005d': 366,
#  '0x1211f20': 367,
#  'readfile': 368,
#  'virtualfree': 369,
#  'kernel32readfile': 370,
#  '0x28fd0': 371,
#  '0x7aa0': 372,
#  'write': 373,
#  'kernel32exitprocess': 374,
#  '0xfeee0046': 375,
#  'sleep': 376,
#  '0xfeee002c': 377,
#  'user32wsprintfw': 378,
#  'gdi32getdevicecaps': 379,
#  '0x401468': 380,
#  '0x1211cc0': 381,
#  '0xfeee002d': 382,
#  '0xfeee002b': 383,
#  '0x1211fd0': 384,
#  '0xfeee002f': 385,
#  '0xfeee00f1': 386,
#  '0xfeee002e': 387,
#  '0x88a0': 388,
#  '0x8d00': 389,
#  'user32dll': 390,
#  'open': 391,
#  'getlasterror': 392,
#  'advapi32dll': 393,
#  '0x78c0': 394,
#  '0xfeee007c': 395,
#  'getmodulehandlea': 396,
#  '0xfeee0030': 397,
#  '0xfeee0074': 398,
#  '0xfeee006b': 399,
#  '0xfeee0045': 400,
#  '0x3394': 401,
#  '0xfeee0031': 402,
#  '0xa000': 403,
#  '0x214': 404,
#  '0xfeee006d': 405,
#  '0x9010': 406,
#  'kernel32initializeslisthead': 407,
#  '0xfeee0044': 408,
#  '0x4790': 409,
#  '0xfeee0034': 410,
#  '0xfeee005e': 411,
#  '0x42c508': 412,
#  '0xfeee0032': 413,
#  'drivewindowstempgolfinfoini': 414,
#  '0xfeee0033': 415,
#  '0xfeee0043': 416,
#  '0xfeee0035': 417,
#  '0xfeee0047': 418,
#  '0xfeee0036': 419,
#  '0xfeee0048': 420,
#  '0xfeee003b': 421,
#  '0xfeee0037': 422,
#  '0x7bd0': 423,
#  '0xfeee0049': 424,
#  'getcurrentthreadid': 425,
#  '0xfeee0038': 426,
#  '0xfeee0039': 427,
#  '0x1211fcc': 428,
#  '0x2e': 429,
#  '0xfeee0041': 430,
#  '0x7990': 431,
#  '0xfeee003f': 432,
#  '0xfeee0042': 433,
#  '0xfeee003a': 434,
#  '0xfeee003d': 435,
#  '0xfeee003e': 436,
#  '0xfeee003c': 437,
#  '0x1211fc0': 438,
#  '0xfeee0062': 439,
#  'gettickcount': 440,
#  '0x7150': 441,
#  '0x1211948': 442,
#  '0xfeee0053': 443,
#  '0xfeee004a': 444,
#  '0xfeee0060': 445,
#  '0xfeee005c': 446,
#  '0xfeee004b': 447,
#  '0x72a0': 448,
#  '0xfeee004d': 449,
#  '0xfeee004c': 450,
#  '0xfeee005a': 451,
#  '0xd0': 452,
#  '0x73f0': 453,
#  '0xfeee0050': 454,
#  '0xfeee004e': 455,
#  '0xfeee0055': 456,
#  '0xfeee005b': 457,
#  '0x7d10': 458,
#  '0xfeee0051': 459,
#  '0xfeee0052': 460,
#  '0xfeee004f': 461,
#  '0xfeee0054': 462,
#  '0xfeee0061': 463,
#  '0xfeee0057': 464,
#  '0xfeee0056': 465,
#  '0xfeee0065': 466,
#  '0xfeee0063': 467,
#  '0x1211568': 468,
#  '0xfeee0058': 469,
#  '0xfeee0066': 470,
#  '0xfeee0059': 471,
#  '0xfeee0067': 472,
#  'setfilepointer': 473,
#  'user32setmenuinfo': 474,
#  '0x42c4d8': 475,
#  '0x7690': 476,
#  '0x77e0': 477,
#  '0xfeee0068': 478,
#  'kernel32lstrlena': 479,
#  '0xfeee0064': 480,
#  '0xfeee0073': 481,
#  '0x1211fc8': 482,
#  'createfilea': 483,
#  '0xfeee0070': 484,
#  '0xfeee0075': 485,
#  '0xfeee006c': 486,
#  '0xfeee006a': 487,
#  'getmodulefilenamea': 488,
#  '0xfeee006f': 489,
#  '0xfeee006e': 490,
#  '0x7d50': 491,
#  '0xfeee0069': 492,
#  '0x436390': 493,
#  'kernel32getsystemdirectoryw': 494,
#  '0x48': 495,
#  '0x4c46d0': 496,
#  'apimswincorelocalizationl121': 497,
#  '0x19': 498,
#  '0x4d70': 499,
#  '0x42d508': 500,
#  '0x28': 501,
#  '0x1211ee0': 502,
#  '0x1211bc0': 503,
#  'freelibrary': 504,
#  'kernel32virtualfree': 505,
#  '0x4305b0': 506,
#  '0x40a5ce': 507,
#  '0x40a5d0': 508,
#  '0x40a5d2': 509,
#  '0x40a5d4': 510,
#  '0x40a5d6': 511,
#  '0x40a5d8': 512,
#  '0x40a5da': 513,
#  '0xfeee0077': 514,
#  'createfilew': 515,
#  '0xfeee0079': 516,
#  '0xfeee0078': 517,
#  '0xfeee0076': 518,
#  '0xfeee007a': 519,
#  'createthread': 520,
#  '0xfeee0081': 521,
#  '0x12119ac': 522,
#  'getfilesize': 523,
#  '0x42d4d8': 524,
#  'comparestringex': 525,
#  'getlocaleinfoex': 526,
#  '0xfde9': 527,
#  '0x1e': 528,
#  '0xfeee009a': 529,
#  'getmodulehandlew': 530,
#  '0x23': 531,
#  'regclosekey': 532,
#  'deletefilew': 533,
#  'createsymboliclinkw': 534,
#  '0x1a': 535,
#  '0x53000': 536,
#  'getmodulefilenamew': 537,
#  '0x21000': 538,
#  '0x1211e14': 539,
#  'kernel32lread': 540,
#  'process32next': 541,
#  '0x1211f2c': 542,
#  '0x1f400': 543,
#  '0xfeee007b': 544,
#  'getcommandlinew': 545,
#  'getcurrentpackageid': 546,
#  'createsemaphoreexw': 547,
#  'createthreadpooltimer': 548,
#  'setthreadpooltimer': 549,
#  'waitforthreadpooltimercallbacks': 550,
#  'closethreadpooltimer': 551,
#  'createthreadpoolwait': 552,
#  'setthreadpoolwait': 553,
#  'closethreadpoolwait': 554,
#  'flushprocesswritebuffers': 555,
#  'freelibrarywhencallbackreturns': 556,
#  'getcurrentprocessornumber': 557,
#  '0x1211fc4': 558,
#  'getsystemtimeasfiletime': 559,
#  'user32getdc': 560,
#  'user32releasedc': 561,
#  'kernel32createfilea': 562,
#  '0x79d0': 563,
#  '0x435390': 564,
#  '0x121194c': 565,
#  '0x12117a4': 566,
#  '0x121157c': 567,
#  'ntdlldll': 568,
#  '0xfeee0089': 569,
#  '0xfeee008a': 570,
#  '0xfeee007f': 571,
#  'msvcrtstrncmp': 572,
#  'isprocessorfeaturepresent': 573,
#  'getfileattributesw': 574,
#  '0x1211dcc': 575,
#  'kernel32findresourceexw': 576,
#  'shlwapipathappendw': 577,
#  'findclose': 578,
#  '0x3c': 579,
#  'getprocaddress': 580,
#  'temp': 581,
#  '0xfeee0080': 582,
#  '0x38': 583,
#  'kernel32gettempfilenamew': 584,
#  '0x7b40': 585,
#  '0xfeee007d': 586,
#  '0x1211f00': 587,
#  '0x1211fd4': 588,
#  'regsetvalueexw': 589,
#  'openalways': 590,
#  'shell32dll': 591,
#  '0xfeee0082': 592,
#  '0xc00': 593,
#  '0x4feba8': 594,
#  'ntdllntopensection': 595,
#  '0x17': 596,
#  '0x7090': 597,
#  '0x8230': 598,
#  '0x1211e2c': 599,
#  'loadwithalteredsearchpath': 600,
#  '0xfeee0084': 601,
#  'ssdll': 602,
#  'kernel32setdefaultdlldirectories': 603,
#  '0x7ae0': 604,
#  '0x101': 605,
#  'getcurrentdirectoryw': 606,
#  '0xfeee0095': 607,
#  '0x46b0': 608,
#  '0xfeee0087': 609,
#  '0xfeee008e': 610,
#  '0xfeee0088': 611,
#  '0x1211d04': 612,
#  '0xfeee0083': 613,
#  '0xfeee008c': 614,
#  '0xfeee0085': 615,
#  '0xfeee0086': 616,
#  '0x1211a04': 617,
#  '0x7390': 618,
#  '0x1211c04': 619,
#  'registryaccess': 620,
#  '0x1b': 621,
#  '0xfeee008d': 622,
#  'kernel32getcurrentprocess': 623,
#  'globalalloc': 624,
#  '0x8920': 625,
#  '0x7b80': 626,
#  'globalfree': 627,
#  'c': 628,
#  'waitforsingleobject': 629,
#  '0x7db0': 630,
#  '0x3e': 631,
#  '0x78d0': 632,
#  '0x2000': 633,
#  '0x437880': 634,
#  '0x569b00': 635,
#  'setfileattributesw': 636,
#  '0x7270': 637,
#  '0xfeee008f': 638,
#  '0xfeee0090': 639,
#  '0x1211dd4': 640,
#  '0x71b0': 641,
#  '0x75d0': 642,
#  '0x7870': 643,
#  '0x1211efc': 644,
#  'cwindowstempgolfinfoini': 645,
#  '0x7030': 646,
#  'user32peekmessagea': 647,
#  '0x7d94': 648,
#  '0x7d95': 649,
#  '0xfeee0092': 650,
#  '0x94c0': 651,
#  'read': 652,
#  '0x42dac6': 653,
#  '0x7060': 654,
#  '0x7b10': 655,
#  '0x71e0': 656,
#  'globalunlock': 657,
#  '0xfeee0094': 658,
#  'globallock': 659,
#  'createalways': 660,
#  '0x7210': 661,
#  '0x74e0': 662,
#  '0x7240': 663,
#  '0x72d0': 664,
#  '0xfeee0091': 665,
#  '0x7750': 666,
#  '0x7a50': 667,
#  '0x70c0': 668,
#  '0x7180': 669,
#  '0x7120': 670,
#  '0x8090': 671,
#  '0x70f0': 672,
#  '0x7300': 673,
#  '0x7330': 674,
#  '0x7480': 675,
#  '0x7cf0': 676,
#  'wakeallconditionvariable': 677,
#  '0xfeee0093': 678,
#  '0x7600': 679,
#  '0x7360': 680,
#  '0x7660': 681,
#  '0x73c0': 682,
#  '0x7720': 683,
#  '0x7ba0': 684,
#  '0x75a0': 685,
#  '0x7570': 686,
#  '0x7840': 687,
#  '0x76f0': 688,
#  '0x76c0': 689,
#  '0x74b0': 690,
#  '0x7420': 691,
#  '0x7510': 692,
#  '0xfeee0098': 693,
#  '0x7a20': 694,
#  '0x7450': 695,
#  '0xfeee0097': 696,
#  '0x77b0': 697,
#  '0xfeee0096': 698,
#  '0xfeee0099': 699,
#  '0x7630': 700,
#  '0x79c0': 701,
#  '0x1211fac': 702,
#  '0x7960': 703,
#  '0x7900': 704,
#  '0x7780': 705,
#  '0x1211f28': 706,
#  '0x7b70': 707,
#  'sleepconditionvariablecs': 708,
#  '0x78f0': 709,
#  '0x9030': 710,
#  '0x121193c': 711,
#  '0x7be0': 712,
#  'kernel32globalalloc': 713,
#  '0xfeee009b': 714,
#  '0xfeee009c': 715,
#  'kernel32tryacquiresrwlockexclusive': 716,
#  'postquitmessage': 717,
#  'beginpaint': 718,
#  'endpaint': 719,
#  '0x24': 720,
#  '0x42': 721,
#  'createdirectoryw': 722,
#  'deletefilea': 723,
#  '0x44f8e0': 724,
#  'getcommandlinea': 725,
#  '0x42a9a0': 726,
#  '0x1211508': 727,
#  '0x2f': 728,
#  '0x33': 729,
#  '0x7bf0': 730,
#  '0x7b90': 731,
#  '0x1211cdc': 732,
#  'createtoolhelp32snapshot': 733,
#  '0x25': 734,
#  'advapi32regopenkeyexa': 735,
#  '0x1211928': 736,
#  'user32wsprintfa': 737,
#  'kingkarton10': 738,
#  'kingkarton': 739,
#  'ws232dll': 740,
#  'user32createwindowexa': 741,
#  'heapalloc': 742,
#  '0x1211f04': 743,
#  '0x80000000': 744,
#  '0x12117f8': 745,
#  '0x47c0': 746,
#  'setevent': 747,
#  'translatemessage': 748,
#  'resumethread': 749,
#  '0x1211578': 750,
#  'pffloatingpointprecisionerrata': 751,
#  '0x15': 752,
#  '0x65500000': 753,
#  '0x1211308': 754,
#  'multibytetowidechar': 755,
#  '0x41bc20': 756,
#  'getuserdefaultlocalename': 757,
#  'heapfree': 758,
#  'getdateformatex': 759,
#  'softwaremicrosoftwindowsntcurrentversionfontsubstitutes': 760,
#  'gettimeformatex': 761,
#  'enumsystemlocalesex': 762,
#  'isvalidlocalename': 763,
#  'findfirstfilew': 764,
#  'kernel32getsysteminfo': 765,
#  'kernel32seterrormode': 766,
#  '0x5a': 767,
#  'widechartomultibyte': 768,
#  '0x1211f4c': 769,
#  '0x1211f34': 770,
#  'exitthread': 771,
#  'getprocessheap': 772,
#  '0x7cd0': 773,
#  'may': 774,
#  '0x10000': 775,
#  '0xb8': 776,
#  'findnextfilew': 777,
#  '0x3bc': 778,
#  '0x42b9a0': 779,
#  'createprocessa': 780,
#  'terminatethread': 781,
#  'copyfilew': 782,
#  '0x7df0': 783,
#  'localalloc': 784,
#  'getstdhandle': 785,
#  'createdirectorya': 786,
#  'kernel32process32nextw': 787,
#  'entercriticalsection': 788,
#  'leavecriticalsection': 789,
#  '0x5265c28': 790,
#  '0x16': 791,
#  'kernel32deletefilew': 792,
#  'deletecriticalsection': 793,
#  'getcurrentprocess': 794,
#  'getlogicalprocessorinformation': 795,
#  '0xffff': 796,
#  'gdi32getsystempaletteentries': 797,
#  'createprocessw': 798,
#  'setthreadstackguarantee': 799,
#  '0x409340': 800,
#  '0x40933d': 801,
#  '0x40933e': 802,
#  'getcurrentprocessid': 803,
#  '0x40933f': 804,
#  '0x409341': 805,
#  '0x409342': 806,
#  '0x409343': 807,
#  'isdebuggerpresent': 808,
#  '0x67000000': 809,
#  '0x3f3000': 810,
#  'getacp': 811,
#  '0x6d': 812,
#  '0x1211ef0': 813,
#  'closeservicehandle': 814,
#  '0x3f34c0': 815,
#  '0x1211f88': 816,
#  'terminateprocess': 817,
#  'tlsgetvalue': 818,
#  'openscmanagerw': 819,
#  'tlssetvalue': 820,
#  'unhandledexceptionfilter': 821,
#  'getcpinfo': 822,
#  '0x22': 823,
#  'getenvironmentvariablea': 824,
#  'rtlunwind': 825,
#  'kernel32createeventw': 826,
#  'setlasterror': 827,
#  '0x42d8c6': 828,
#  'kernel32globallock': 829,
#  '0x107568': 830,
#  'getenvironmentvariablew': 831,
#  '0x4c42d8': 832,
#  '0x4c42f0': 833,
#  '0x7af0': 834,
#  '0x3f2000': 835,
#  'getfiletype': 836,
#  'getusernamew': 837,
#  '0x21': 838,
#  'dispatchmessagea': 839,
#  '0x8f20': 840,
#  '0x43b390': 841,
#  '0xd000': 842,
#  'initializesecuritydescriptor': 843,
#  'setsecuritydescriptordacl': 844,
#  'heaprealloc': 845,
#  '0x8a80': 846,
#  'interlockedincrement': 847,
#  'interlockeddecrement': 848,
#  'getmessagea': 849,
#  '0x1211f3c': 850,
#  '0x60000': 851,
#  'raiseexception': 852,
#  'setunhandledexceptionfilter': 853,
#  'tlsalloc': 854,
#  '0x433648': 855,
#  '0x1211bfc': 856,
#  'getstringtypew': 857,
#  'gettickcount64': 858,
#  'getoemcp': 859,
#  'createeventexw': 860,
#  '0x8814': 861,
#  'flushfilebuffers': 862,
#  '0x7d98': 863,
#  '0x7d99': 864,
#  'lcmapstringw': 865,
#  '0x1211cfc': 866,
#  '0x29': 867,
#  '0x1211768': 868,
#  'kernel32getsystemdirectorya': 869,
#  '0x4620': 870,
#  '0x1211dc8': 871,
#  '0x120e6d4': 872,
#  '0x9020': 873,
#  'gdi32dll': 874,
#  'heapcreate': 875,
#  '0x8280': 876,
#  'getenvironmentstringsw': 877,
#  'freeenvironmentstringsw': 878,
#  '0x7da0': 879,
#  'setfileattributesa': 880,
#  '0x7de4': 881,
#  '0x6c': 882,
#  '0x7de5': 883,
#  '0x8815': 884,
#  '0x7d9c': 885,
#  'kernel32deletecriticalsection': 886,
#  '0x7d9d': 887,
#  '0x120e6d0': 888,
#  '0x36': 889,
#  '0x7da1': 890,
#  'getsystemmetrics': 891,
#  '0x12117e8': 892,
#  '0x12117fc': 893,
#  'setstdhandle': 894,
#  '0x7db4': 895,
#  '0x7da4': 896,
#  '0x8a60': 897,
#  '0x410770': 898,
#  '0x7db5': 899,
#  'initializecriticalsectionandspincount': 900,
#  '0x1211fdc': 901,
#  '0x7da5': 902,
#  'copyfilea': 903,
#  '0x4a': 904,
#  '0x1211e08': 905,
#  '0x527ed8': 906,
#  '0x7da8': 907,
#  '0x1211f48': 908,
#  '0x45fc': 909,
#  'regopenkeyexa': 910,
#  'getdc': 911,
#  '0x4800': 912,
#  '0x7da9': 913,
#  '0x1211e40': 914,
#  'kernel32loadresource': 915,
#  '0x7e74': 916,
#  'virtualprotect': 917,
#  '0x7e75': 918,
#  'setwindowpos': 919,
#  '0x7e78': 920,
#  '0x7e79': 921,
#  'deleteobject': 922,
#  '0x7e80': 923,
#  'crtdllgetmainargs': 924,
#  '0x7e7c': 925,
#  '0x8cf0': 926,
#  'getforegroundwindow': 927,
#  '0x7e7d': 928,
#  '0x66': 929,
#  'selectobject': 930,
#  'kernel32findresourcew': 931,
#  '0x68': 932,
#  'deletedc': 933,
#  'getkeystate': 934,
#  'sethandlecount': 935,
#  'softwareborlandlocales': 936,
#  '0x7dac': 937,
#  'kernel32createeventa': 938,
#  '0x7dad': 939,
#  '0x7e81': 940,
#  'user32getsyscolorbrush': 941,
#  'queryperformancecounter': 942,
#  'kernel32sizeofresource': 943,
#  '0x8d80': 944,
#  'settextcolor': 945,
#  'softwarecodegearlocales': 946,
#  'tlsfree': 947,
#  '0x1d': 948,
#  '0x7db1': 949,
#  '0x8410': 950,
#  'setbkcolor': 951,
#  '0x7e84': 952,
#  'kernel32loadlibraryw': 953,
#  '0x7e85': 954,
#  '0x4340c8': 955,
#  '0xff': 956,
#  '0x8330': 957,
#  'kernel32getlocaltime': 958,
#  'kernel32lockresource': 959,
#  'user32registerclassa': 960,
#  'setendoffile': 961,
#  '0x3d': 962,
#  '0x6b': 963,
#  'createeventa': 964,
#  'process32first': 965,
#  'showwindow': 966,
#  '0x8340': 967,
#  '0x42c588': 968,
#  '0x3e6c': 969,
#  'winexec': 970,
#  'msvcrtinitterm': 971,
#  'getlogicaldrivestringsa': 972,
#  '0x571b00': 973,
#  '0x7db8': 974,
#  'user32registerwindowmessagew': 975,
#  '0x7db9': 976,
#  '0x4710': 977,
#  'updatewindow': 978,
#  '0x1211ec8': 979,
#  '0x7dbc': 980,
#  '0x7dbd': 981,
#  '0x40a5dc': 982,
#  '0x40a5cc': 983,
#  'mapviewoffile': 984,
#  '0x8d10': 985,
#  'kernel32getenvironmentvariablew': 986,
#  'createcompatibledc': 987,
#  'kernel32verifyversioninfow': 988,
#  'bitblt': 989,
#  '0x4169c0': 990,
#  '0x4169c1': 991,
#  'loadicona': 992,
#  '0x46': 993,
#  'heapsize': 994,
#  '0x3f30b0': 995,
#  'ole32coinitializeex': 996,
#  '0x3f30e0': 997,
#  '0x3f3030': 998,
#  '0x3f3110': 999,
#  ...}

# %%
x_baseline = tokenize_sample(baseline_report)
x_embed_baseline = embed(model, baseline_report)

print(f"\n[!!!] MALWARE FOLDER")
filepaths, explanations = analyse_folder(malware_folder, model_no_embed, x_embed_baseline, "malware")

print(f"\n[!!!] GOODWARE FOLDER")
_ = analyse_folder(goodware_folder, model_no_embed, x_embed_baseline, "goodware")
# Out:
# [!!!] MALWARE FOLDER
# 0a0358122fbf7713bc100f9d0757747e991079c1f7a393aacb5c1fcbe1ff7065.dat.json
#
# [!!!] Probability of being malicious: 0.979 | Logit: 3.859
# 0a677fb789978cdd22f6c0c66a5cf01a9e2fd6d9fcb6484b2385d9354f0632f2.dat.json
#
# [!!!] Probability of being malicious: 0.800 | Logit: 1.388
# 0a711ca925166cadd3c73802b3ba569bf6a6f951fded4c60ccc6ecc2c756473d.dat.json
#
# [!!!] Probability of being malicious: 0.732 | Logit: 1.006
# 0afa6b5d80f2f3a56c9144d2033b3ea168abb86bbe5e26bc71eccbcf8a0be93a.dat.json
#
# [!!!] Probability of being malicious: 0.913 | Logit: 2.345
# 0b1e9a9d060e20685b2718d0a6667e76459ca141ea062b883873ceaa16afb5d9.dat.json
#
# [!!!] Probability of being malicious: 0.761 | Logit: 1.158
# 0b30e9492b3d43bddf9be4d2f29441f2318b2958e37cfda8efc07f5257c949c9.dat.json
#
# [!!!] Probability of being malicious: 0.998 | Logit: 6.498
# 0b6a25fdef6575f6aea7941c63a8a0a740a6754acae7d32f5a590dcae01d27fc.dat.json
#
# [!!!] Probability of being malicious: 0.994 | Logit: 5.081
# 0b6c3923a7d34f3062dab70853887a2a3c8bdb009e9a110d4a554bef892b26fd.dat.json
#
# [!!!] Probability of being malicious: 0.001 | Logit: -7.157
# [!!!] GOODWARE FOLDER
# 0a0ba23720d5afda91ccb93bda9e560473cce055bf2f516d36cc23a9c3a42e60.dat.json
#
# [!!!] Probability of being malicious: 0.017 | Logit: -4.067
# 0a1e8fd4416c21fa74171048a53eaeeb958d77b1c44986633110c01c0c91b38e.dat.json
#
# [!!!] Probability of being malicious: 0.000 | Logit: -8.590
# 0a2b0354ac9b5ec2967412f0577f2f803b93693283101b417eba342ce1205eaa.dat.json
#
# [!!!] Probability of being malicious: 0.001 | Logit: -6.603
# 0a3bbeb27e09ef22c94f7440d07bedde479e0e9f122fe51b6f86b4634120221b.dat.json
#
# [!!!] Probability of being malicious: 0.018 | Logit: -3.992
# 0a4a72fe3cc032f6270ffbd460bb1e68ef005795334e3e478e95965469591681.dat.json
#
# [!!!] Probability of being malicious: 0.226 | Logit: -1.229
# 0a4e5a5bb11126116ea610019c1ec5ee5d3a3312dfa1975f94acc13eb1545d58.dat.json
#
# [!!!] Probability of being malicious: 0.006 | Logit: -5.166
# 0a57cc32471142bd98fd1aa1004826a03edfef99698d990cd4c5a746c78a65ff.dat.json
#
# [!!!] Probability of being malicious: 0.504 | Logit: 0.016
# 0a5efb412ca54bce23961cef891c28e0e76a5bef2aa776f35374f4d7bfec9aa5.dat.json
#
# [!!!] Probability of being malicious: 0.004 | Logit: -5.573

# %%
def plot_importance(filepaths, explanations, idx=None, start=0, end=100, token_max_len=20):
    """
    It should plot the string values along y-axis and plot bars
    with length and color equal to the float values in red/orange heatmap colorscheme.
    """
    if idx is None:
        idxs = range(len(filepaths))
    else:
        idxs = [idx]
    for idx in idxs:
        sample_values = explanations[idx].mean(axis=2)[:,start:end][0].tolist()[::-1]
        sample_tokens = tokenize_sample(os.path.join(malware_folder, filepaths[idx]), encode=False)
        sample_tokens = sample_tokens[start:end][::-1]
        # limit length of every element in sample tokens to max 15 chars
        sample_tokens = [token[:token_max_len] for token in sample_tokens]

        ysize = len(sample_tokens) * 0.25
        fig, ax = plt.subplots(figsize=(10, ysize))
        x = range(len(sample_tokens))    
        # assign color to each bar based on value:
        # -- the higher value, the more red
        # -- if value is below 0, then use blue instead of red
        colors = []
        mmax = max(sample_values)
        mmin = min(sample_values)
        for value in sample_values:
            if value > 0:
                c = plt.cm.Reds(value / mmax)
            else:
                c = plt.cm.Blues(value / mmin)
            colors.append(c)
        plt.barh(x, sample_values, color=colors)
        plt.yticks(x, sample_tokens)

        # compute_score
        x = tokenize_sample(os.path.join(malware_folder, filepaths[idx]))
        prob = compute_score(model, x, verbose=False)
        plt.title(f"{filepaths[idx]} : {prob:.3f}")

plot_importance( # just first 3 samples for now
    filepaths=filepaths[0:3],
    explanations=explanations[0:3],
    idx=None,
    end=512
)
