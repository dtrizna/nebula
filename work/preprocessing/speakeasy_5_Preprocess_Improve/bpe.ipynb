# %%
import orjson
import time
import logging

import os
import sys
sys.path.extend([".", "../.."])
from nebula.misc import get_path
from nebula import PEDynamicFeatureExtractor, JSONTokenizer

SCRIPT_PATH = get_path(type="notebook")

# %%
SPEAKEASY_RECORD_FIELDS = [
    'file_access.event',
    'file_access.path',
    'network_events.traffic.server',
    'network_events.traffic.port',
    'registry_access.event',
    'registry_access.path',
    'apis.api_name',
    'apis.args',
    'apis.ret_val',
]
SPEAKEASY_RECORD_LIMITS = {"network_events.traffic": 256}
JSON_CLEANUP_SYMBOLS = ['"', "'", ":", ",", "[", "]", "{", "}", "\\", "/"]
BENIGN_FOLDERS = ["report_clean", "report_windows_syswow64"]

REPO_ROOT = os.path.join(SCRIPT_PATH, "..", "..")
EMULATION_TRAINSET_PATH = os.path.join(REPO_ROOT, "data", "data_raw", "windows_emulation_trainset")
EMULATION_TESTSET_PATH = os.path.join(REPO_ROOT, "data", "data_raw", "windows_emulation_testset")

extractor = PEDynamicFeatureExtractor(
    speakeasyRecordFields=SPEAKEASY_RECORD_FIELDS,
    recordLimits=SPEAKEASY_RECORD_LIMITS
)

def readAndFilterFolders(subFolders, parserFunction, limit=None):
    """
    Reads and filters all json files in subFolders. Returns a list of events and a list of y values.
    """
    events = []
    y = []
    yHashes = []
    for subFolder in subFolders:
        
        files = [os.path.join(subFolder,x) for x in os.listdir(subFolder)[:limit] if x.endswith(".json")]
        for file in files:
            with open(file, "r") as f:
                entryPoints = orjson.loads(f.read())

            jsonEventRecord = parserFunction(entryPoints)
            if jsonEventRecord:
                events.append(jsonEventRecord)
                
                hhash = os.path.basename(file).rstrip('.json')
                yHashes.append(hhash)
                if os.path.basename(subFolder) in BENIGN_FOLDERS:
                    y.append(0)
                else:
                    y.append(1)
    return events, y, yHashes

subFoldersTrain = [os.path.join(EMULATION_TRAINSET_PATH, x) for x in os.listdir(EMULATION_TRAINSET_PATH) if x.startswith("report_")]

eventsTrain, yTrain, yHashesTrain = readAndFilterFolders(subFoldersTrain, extractor.filter_and_normalize_report, limit=100)

# %%
eventsTrain[0:1]
# Out:
# [{'file_access': [{'event': 'create',
#     'path': '<drive>\\windows\\temp\\golfinfo.ini'},
#    {'event': 'create', 'path': '<drive>\\windows\\temp\\golfset.ini'},
#    {'event': 'create', 'path': '<drive>\\windows\\temp\\golfinfo.ini'},
#    {'event': 'write', 'path': '<drive>\\windows\\temp\\golfinfo.ini'},
#    {'event': 'open', 'path': '<drive>\\windows\\system32\\<sha256>'},
#    {'event': 'read', 'path': '<drive>\\windows\\system32\\<sha256>'},
#    {'event': 'create', 'path': 'cd.exedows\\temp\\hgdraw.dll'},
#    {'event': 'write', 'path': 'cd.exedows\\temp\\hgdraw.dll'}],
#   'apis': [{'api_name': 'KERNEL32.GetSystemTimeAsFileTime',
#     'args': ['0x1211fd8'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetCurrentProcessId',
#     'args': [],
#     'ret_val': '0x7e148'},
#    {'api_name': 'KERNEL32.GetCurrentThreadId',
#     'args': [],
#     'ret_val': '0x7e15c'},
#    {'api_name': 'KERNEL32.GetTickCount', 'args': [], 'ret_val': '0x5265c14'},
#    {'api_name': 'KERNEL32.QueryPerformanceCounter',
#     'args': ['0x1211fd0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetStartupInfoW',
#     'args': ['0x1211f7c'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapSetInformation',
#     'args': ['0x0', '0x1', '0x0', '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.HeapCreate',
#     'args': ['0x0', '0x1000', '0x0'],
#     'ret_val': '0x46d0'},
#    {'api_name': 'KERNEL32.GetModuleHandleW',
#     'args': ['KERNEL32.DLL'],
#     'ret_val': '0x77000000'},
#    {'api_name': 'KERNEL32.GetProcAddress',
#     'args': ['0x77000000', 'FlsAlloc'],
#     'ret_val': '0xfeee0000'},
#    {'api_name': 'KERNEL32.GetProcAddress',
#     'args': ['0x77000000', 'FlsGetValue'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'KERNEL32.GetProcAddress',
#     'args': ['0x77000000', 'FlsSetValue'],
#     'ret_val': '0xfeee0002'},
#    {'api_name': 'KERNEL32.GetProcAddress',
#     'args': ['0x77000000', 'FlsFree'],
#     'ret_val': '0xfeee0003'},
#    {'api_name': 'KERNEL32.TlsAlloc', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsSetValue',
#     'args': ['0x0', '0xfeee0001'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EncodePointer', 'args': ['0x0'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0x414253'],
#     'ret_val': '0x414254'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0xfeee0000'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0xfeee0001'],
#     'ret_val': '0xfeee0002'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0xfeee0002'],
#     'ret_val': '0xfeee0003'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0xfeee0003'],
#     'ret_val': '0xfeee0004'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424458', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424470', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424488', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x4244a0', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x4244b8', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x4244d0', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x4244e8', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424500', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424518', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424530', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424548', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424560', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424578', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x424590', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.DecodePointer',
#     'args': ['0xfeee0001'],
#     'ret_val': '0xfeee0000'},
#    {'api_name': 'kernel32.FlsAlloc', 'args': ['0x40ca59'], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x214'],
#     'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.DecodePointer',
#     'args': ['0xfeee0003'],
#     'ret_val': '0xfeee0002'},
#    {'api_name': 'kernel32.FlsSetValue',
#     'args': ['0x0', '0x46f0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetModuleHandleW',
#     'args': ['KERNEL32.DLL'],
#     'ret_val': '0x77000000'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InterlockedIncrement',
#     'args': ['0x422460'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424518'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InterlockedIncrement',
#     'args': ['0x422af0'],
#     'ret_val': '0x2'},
#    {'api_name': 'KERNEL32.InterlockedIncrement',
#     'args': ['0x422a3c'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424518'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetCurrentThreadId',
#     'args': [],
#     'ret_val': '0x7e15c'},
#    {'api_name': 'KERNEL32.GetStartupInfoW',
#     'args': ['0x1211f18'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x800'],
#     'ret_val': '0x7000'},
#    {'api_name': 'KERNEL32.GetStdHandle',
#     'args': ['0xfffffff6'],
#     'ret_val': '0xf001'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0xf001'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x700c', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetStdHandle',
#     'args': ['0xfffffff5'],
#     'ret_val': '0xf002'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0xf002'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x704c', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetStdHandle',
#     'args': ['0xfffffff4'],
#     'ret_val': '0xf003'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0xf003'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x708c', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.SetHandleCount',
#     'args': ['0x20'],
#     'ret_val': '0x20'},
#    {'api_name': 'KERNEL32.GetCommandLineW', 'args': [], 'ret_val': '0x7810'},
#    {'api_name': 'KERNEL32.GetEnvironmentStringsW',
#     'args': [],
#     'ret_val': '0x7850'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x19a'],
#     'ret_val': '0x79f0'},
#    {'api_name': 'KERNEL32.FreeEnvironmentStringsW',
#     'args': ['0x7850'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetModuleFileNameW',
#     'args': ['0x0',
#      'C:\\Windows\\system32\\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a',
#      '0x104'],
#     'ret_val': '0x54'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x44'],
#     'ret_val': '0x7b90'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x8'],
#     'ret_val': '0x7be0'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x198'],
#     'ret_val': '0x7bf0'},
#    {'api_name': 'KERNEL32.HeapFree',
#     'args': ['0x46d0', '0x0', '0x79f0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0x41573d'],
#     'ret_val': '0x41573e'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x80'],
#     'ret_val': '0x7d90'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0x7d90'],
#     'ret_val': '0x7d91'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x8', '0x800'],
#     'ret_val': '0x8000'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetACP', 'args': [], 'ret_val': '0x4e4'},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x220'],
#     'ret_val': '0x8810'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.IsValidCodePage',
#     'args': ['0x4e4'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetCPInfo',
#     'args': ['0x4e4', '0x1211ee0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetCPInfo',
#     'args': ['0x4e4', '0x12119ac'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4',
#      '0x1',
#      '!"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~!@',
#      '0x100',
#      '0x0',
#      '0x0'],
#     'ret_val': '0x10c'},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4', '0x1', '0x1211dc0', '0x100', '0x1211718', '0x10c'],
#     'ret_val': '0x100'},
#    {'api_name': 'KERNEL32.GetStringTypeW',
#     'args': ['0x1', '0x1211718', '0x100', '0x12119c0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4',
#      '0x1',
#      '!"#$%&\'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\\]^_`abcdefghijklmnopqrstuvwxyz{|}~!@',
#      '0x100',
#      '0x0',
#      '0x0'],
#     'ret_val': '0x10c'},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4', '0x1', '0x1211dc0', '0x100', '0x12116d8', '0x10c'],
#     'ret_val': '0x100'},
#    {'api_name': 'KERNEL32.LCMapStringW',
#     'args': ['0x0', '0x100', '0x12116d8', '0x10c', '0x0', '0x0'],
#     'ret_val': '0x10c'},
#    {'api_name': 'KERNEL32.LCMapStringW',
#     'args': ['0x0', '0x100', '0x12116d8', '0x10c', '0x12114b8', '0x10c'],
#     'ret_val': '0x10c'},
#    {'api_name': 'KERNEL32.WideCharToMultiByte',
#     'args': ['0x4e4',
#      '0x0',
#      '0x12114b8',
#      '0x10c',
#      '0x1211cc0',
#      '0x100',
#      '0x0',
#      '0x0'],
#     'ret_val': '0x100'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4', '0x1', '', '0x1', '0x0', '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.MultiByteToWideChar',
#     'args': ['0x4e4', '0x1', '0x1211dc0', '0x1', '0x1211918', '0x1'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LCMapStringW',
#     'args': ['0x0', '0x200', '0x1211918', '0x1', '0x0', '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LCMapStringW',
#     'args': ['0x0', '0x200', '0x1211918', '0x1', '0x1211908', '0x1'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.WideCharToMultiByte',
#     'args': ['0x4e4',
#      '0x0',
#      '0x1211908',
#      '0x1',
#      '0x1211bc0',
#      '0x100',
#      '0x0',
#      '0x0'],
#     'ret_val': '0x100'},
#    {'api_name': 'KERNEL32.InterlockedDecrement',
#     'args': ['0x422460'],
#     'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.InterlockedIncrement',
#     'args': ['0x8810'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InterlockedDecrement',
#     'args': ['0x422460'],
#     'ret_val': '0xffffffff'},
#    {'api_name': 'KERNEL32.InterlockedIncrement',
#     'args': ['0x8810'],
#     'ret_val': '0x2'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424530'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.IsProcessorFeaturePresent',
#     'args': ['PF_XMMI64_INSTRUCTIONS_AVAILABLE'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.SetUnhandledExceptionFilter',
#     'args': ['0x41227e'],
#     'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x4244e8'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.DecodePointer',
#     'args': ['0x7d91'],
#     'ret_val': '0x7d90'},
#    {'api_name': 'KERNEL32.DecodePointer',
#     'args': ['0x7d91'],
#     'ret_val': '0x7d90'},
#    {'api_name': 'KERNEL32.HeapSize',
#     'args': ['0x46d0', '0x0', '0x7d90'],
#     'ret_val': '0x90'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0x4127bc'],
#     'ret_val': '0x4127bd'},
#    {'api_name': 'KERNEL32.EncodePointer',
#     'args': ['0x7d94'],
#     'ret_val': '0x7d95'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x4244e8'],
#     'ret_val': None},
#    {'api_name': 'USER32.LoadStringW',
#     'args': ['0x400000', '0x67', 'Update_2010', '0x64'],
#     'ret_val': '0x16'},
#    {'api_name': 'USER32.LoadStringW',
#     'args': ['0x400000', '0x6d', 'UPDATE_2010', '0x64'],
#     'ret_val': '0x16'},
#    {'api_name': 'USER32.LoadIconW',
#     'args': ['0x400000', '0x6b'],
#     'ret_val': '0x0'},
#    {'api_name': 'USER32.LoadCursorW',
#     'args': ['0x0', '0x7f00'],
#     'ret_val': '0x4'},
#    {'api_name': 'USER32.LoadIconW',
#     'args': ['0x400000', '0x6c'],
#     'ret_val': '0x0'},
#    {'api_name': 'USER32.RegisterClassExW',
#     'args': ['0x1211af8'],
#     'ret_val': '0x952a0'},
#    {'api_name': 'KERNEL32.GetVersionExW',
#     'args': ['0x1211a08'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.Sleep', 'args': ['0x7d0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetTempPathW',
#     'args': ['0x104', 'C:\\Windows\\temp\\'],
#     'ret_val': '0x10'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x18'],
#     'ret_val': '0x8a40'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x8a40', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x18'],
#     'ret_val': '0x8a60'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x8a60', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.InitializeCriticalSectionAndSpinCount',
#     'args': ['0x70cc', '0xfa0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424500'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CreateFileW',
#     'args': ['C:\\Windows\\temp\\golfinfo.ini',
#      'GENERIC_READ',
#      '0x1',
#      '0x120f93c',
#      'OPEN_EXISTING',
#      '0x80',
#      '0x0'],
#     'ret_val': '0xffffffff'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x2'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetTempPathW',
#     'args': ['0x104', 'C:\\Windows\\temp\\'],
#     'ret_val': '0x10'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CreateFileW',
#     'args': ['C:\\Windows\\temp\\golfset.ini',
#      'GENERIC_READ',
#      '0x1',
#      '0x120fb5c',
#      'OPEN_EXISTING',
#      '0x80',
#      '0x0'],
#     'ret_val': '0xffffffff'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x2'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetModuleFileNameW',
#     'args': ['0x0',
#      'C:\\Windows\\system32\\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a',
#      '0x104'],
#     'ret_val': '0x54'},
#    {'api_name': 'KERNEL32.GetTempPathW',
#     'args': ['0x104', 'C:\\Windows\\temp\\'],
#     'ret_val': '0x10'},
#    {'api_name': 'KERNEL32.GetFileAttributesW',
#     'args': ['C:\\Windows\\temp\\HGDraw.dll'],
#     'ret_val': '0xffffffff'},
#    {'api_name': 'KERNEL32.GetTickCount', 'args': [], 'ret_val': '0x5265c28'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetTempPathW',
#     'args': ['0x104', 'C:\\Windows\\temp\\'],
#     'ret_val': '0x10'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CreateFileW',
#     'args': ['C:\\Windows\\temp\\golfinfo.ini',
#      'GENERIC_WRITE',
#      '0x0',
#      '0x120f950',
#      'CREATE_ALWAYS',
#      '0x80',
#      '0x0'],
#     'ret_val': '0x4ae4'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0x4ae4'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x1000'],
#     'ret_val': '0x9000'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.WriteFile',
#     'args': ['0x4ae4',
#      '0x9000(b2acb2afcdffceffc7ffd1ffcaffcbff)',
#      '0x200',
#      '0x120df04',
#      '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapFree',
#     'args': ['0x46d0', '0x0', '0x9000'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CloseHandle', 'args': ['0x4ae4'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetTempPathW',
#     'args': ['0x104', 'C:\\Windows\\temp\\'],
#     'ret_val': '0x10'},
#    {'api_name': 'USER32.wsprintfW',
#     'args': ['Cd.exe', '%s%s.exe'],
#     'ret_val': '0x6'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CreateFileW',
#     'args': ['C:\\Windows\\system32\\0009064322cdc719a82317553b805cbbc64230a9212d3b8aad1ea1b78d3bf10a',
#      'GENERIC_READ',
#      '0x1',
#      '0x120fd70',
#      'OPEN_EXISTING',
#      '0x80',
#      '0x0'],
#     'ret_val': '0x4ae8'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0x4ae8'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.SetFilePointer',
#     'args': ['0x4ae8', '0x0', '0x0', '0x2'],
#     'ret_val': '0x6f3d0'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.SetFilePointer',
#     'args': ['0x4ae8', '0x0', '0x0', '0x1'],
#     'ret_val': '0x6f3d0'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.SetFilePointer',
#     'args': ['0x4ae8', '0x0', '0x0', '0x0'],
#     'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x6f402'],
#     'ret_val': '0x71000'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.ReadFile',
#     'args': ['0x4ae8', '0x71000', '0x6f000', '0x120fd88', '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapAlloc',
#     'args': ['0x46d0', '0x0', '0x1000'],
#     'ret_val': '0x9000'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.ReadFile',
#     'args': ['0x4ae8', '0x9000', '0x1000', '0x120fd78', '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.HeapFree',
#     'args': ['0x46d0', '0x0', '0x9000'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CloseHandle', 'args': ['0x4ae8'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.GetTickCount', 'args': [], 'ret_val': '0x5265c3c'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x424470'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a60'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CreateFileW',
#     'args': ['Cd.exedows\\temp\\HGDraw.dll',
#      'GENERIC_WRITE',
#      '0x0',
#      '0x120fd64',
#      'CREATE_ALWAYS',
#      '0x80',
#      '0x0'],
#     'ret_val': '0x4aec'},
#    {'api_name': 'KERNEL32.GetFileType', 'args': ['0x4aec'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.WriteFile',
#     'args': ['0x4aec',
#      '0x71000(4d5a90000300000004000000ffff0000)',
#      '0x6f000',
#      '0x120e30c',
#      '0x0'],
#     'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.GetLastError', 'args': [], 'ret_val': '0x0'},
#    {'api_name': 'KERNEL32.TlsGetValue',
#     'args': ['0x0'],
#     'ret_val': '0xfeee0001'},
#    {'api_name': 'kernel32.FlsGetValue', 'args': ['0x0'], 'ret_val': '0x46f0'},
#    {'api_name': 'KERNEL32.SetLastError', 'args': ['0x0'], 'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x8a40'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.EnterCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None},
#    {'api_name': 'KERNEL32.CloseHandle', 'args': ['0x4aec'], 'ret_val': '0x1'},
#    {'api_name': 'KERNEL32.LeaveCriticalSection',
#     'args': ['0x70cc'],
#     'ret_val': None}]}]

# %%
tokenizer = JSONTokenizer(
    patternCleanup=JSON_CLEANUP_SYMBOLS
)
#tokenizer.clearJsonEvent(eventsTrain)

# %%
import sentencepiece as spm
# spm.SentencePieceTrainer.Train(rf'''--input=auditd_total.cm --model_prefix=auditd --vocab_size=1024 --model_type=bpe --split_by_number=false''')
sp = spm.SentencePieceProcessor()

# %%
print(sp.__class__)
print(tokenizer.tokenizer.__class__)
# Out:
# <class 'sentencepiece.SentencePieceProcessor'>
# <class 'nltk.tokenize.regexp.WhitespaceTokenizer'>

# %%
from nebula.constants import *
import string 
import numpy as np

def get_alphanum_chars(s):
    return ''.join(filter(lambda x: x in string.ascii_letters + string.digits + string.punctuation, s))


class JSONTokenizerBPE:
    def __init__(self,
                model_path=None,
                patternCleanup=JSON_CLEANUP_SYMBOLS,
                stopwords=SPEAKEASY_TOKEN_STOPWORDS,
                specialTokens = ["<unk>", "<pad>", "<mask>"]):
        self.patternCleanup = patternCleanup
        self.stopwords = stopwords

        self.specialTokens = dict(zip(specialTokens, range(len(specialTokens))))
        self.pad_token = "<pad>"
        self.unk_token = "<unk>"
        self.mask_token = "<mask>"
        self.pad_token_id = self.specialTokens[self.pad_token]
        self.unk_token_id = self.specialTokens[self.unk_token]
        self.mask_token_id = self.specialTokens[self.mask_token]

        if model_path:
            self.tokenizer = spm.SentencePieceProcessor(model_file=model_path.rstrip(".model")+".model")
        else:
            self.tokenizer = spm.SentencePieceTrainer
        self.vocab = None
        self.reverse_vocab = None
    
    def split_string_to_chunks(self, s, chunkSize=4192):
        """This function should split a long string into smaller chunks of size chunkSize, 
        but it shouldn't split the string in the middle of a word.

        Args:
            s (str): Longstring
            chunkSize (int, optional): _description_. Defaults to 512.

        Returns:
            list: List of smaller strings
        """
        chunks = []
        words = s.split(" ")
        currentChunk = ""
        for word in words:
            if len(currentChunk) + len(word) < chunkSize:
                currentChunk += word + " "
            else:
                chunks.append(currentChunk)
                currentChunk = word + " "
        chunks.append(currentChunk)
        return chunks

    def clear_json_event(self, jsonData):
        """
        Removes all special characters from the json event.
        """
        assert isinstance(jsonData, (str, bytes, list, dict))
        jsonData = str(jsonData).lower()
        for pattern in self.patternCleanup:
            jsonData = jsonData.replace(pattern, " ")
        jsonData = [get_alphanum_chars(x) for x in jsonData.split(" ") if x not in self.stopwords]
        return ' '.join(jsonData)

    def load_vocab(self):
        with open(self.model_path+".vocab", encoding="utf-8") as f:
            vocab = f.read().splitlines()
        vocab = [x.split("\t")[0] for x in vocab]
        self.vocab = {k:i for i,k in enumerate(vocab)}
        self.reverse_vocab = {v:k for k,v in self.vocab.items()}
        

    def train(self, jsonData, model_prefix="speakeasy", vocab_size=1024, model_type="bpe", split_by_number=False, spLength=4192, removeTrainFiles=True):
        """
        Trains the tokenizer on the given json data.
        """
        jsonDataClean = self.clear_json_event(jsonData)
        # splitting a string into chunks of 4192 characters since this sentencepiece limitation
        jsonDataChunks = self.split_string_to_chunks(jsonDataClean, chunkSize=spLength)
        # dump jsonDataClean to file
        trainFile = f"{model_prefix}_tokenizer_train_{int(time.time())}.txt"
        with open(trainFile, "w", encoding="utf-8") as f:
            f.write("\n".join(jsonDataChunks))

        trainCmd = " ".join([
            f"--input={trainFile}",
            f"--model_prefix={model_prefix}",
            f"--vocab_size={vocab_size}",
            f"--model_type={model_type}",
            f"--split_by_number={split_by_number}",
            f"--max_sentence_length={spLength}",
            f"--max_sentencepiece_length=64"
        ])
        print(f"Training tokenizer with command: {trainCmd}")
        self.tokenizer.Train(trainCmd)
        self.tokenizer = spm.SentencePieceProcessor(model_file=f"{model_prefix}.model")
        
        self.model_path = model_prefix
        self.load_vocab()

        if removeTrainFiles:
            os.remove(trainFile)
            os.remove(f"{model_prefix}.vocab")
    
    def tokenize(self, jsonData):
        """
        Tokenizes the given json data.
        """
        if isinstance(jsonData, (str, bytes, dict)):
            jsonData = [jsonData]
        jsonDataClean = [self.clear_json_event(x) for x in jsonData]
        return [self.tokenizer.encode_as_pieces(x) for x in jsonDataClean]
    
    def encode(self, jsonData):
        """
        Encodes the given json data.
        """
        if isinstance(jsonData, (str, bytes, dict)):
            jsonData = [jsonData]
        jsonDataClean = [self.clear_json_event(x) for x in jsonData]
        return [self.tokenizer.encode_as_ids(x) for x in jsonDataClean]

    def pad_sequence(self, encodedSequence):
        if len(encodedSequence) > self.sequenceLength:
            return encodedSequence[:self.sequenceLength]
        else:
            return encodedSequence + [self.pad_token_id] * (self.sequenceLength - len(encodedSequence))
    
    def pad_sequence_list(self, encodedSequenceList, sequenceLength=512):
        self.sequenceLength = sequenceLength
        return np.array([self.pad_sequence(x) for x in encodedSequenceList], dtype=np.int32)

    def pad_sequences(self, encodedSequences, sequenceLength=512):
        return self.pad_sequence_list(encodedSequences, sequenceLength=sequenceLength)

# %%
t = JSONTokenizerBPE(model_path="speakeasy_2k.model")
t.tokenizer
#prefix=r"speakeasy_2k"
#t.train(eventsTrain, vocab_size=2e3, model_prefix=prefix)
# Out:
# <sentencepiece.SentencePieceProcessor; proxy of <Swig Object of type 'sentencepiece::SentencePieceProcessor *' at 0x0000015C3AE6BCF0> >

# %%
print(t.tokenize(eventsTrain[0:3])[0][0:10])
# Out:
# ['▁file', '_', 'access', '▁create', '▁<', 'drive', '>', '▁windows', '▁temp', '▁golfinfo']

# %%
t.encode(eventsTrain[0])[0][0:10]
# Out:
# [1303, 1983, 946, 346, 724, 771, 1988, 286, 483, 1312]

# %%
t.tokenizer.decode(t.encode(eventsTrain[0:10])[0][0:10])
# Out:
# 'file_access create <drive> windows temp golfinfo'

# %%
encoded = t.encode(eventsTrain[0:10])

print(t.pad_sequences(encoded).shape)
print(t.pad_sequences(encoded, sequenceLength=1024).shape)
# Out:
# (10, 512)
# (10, 1024)
